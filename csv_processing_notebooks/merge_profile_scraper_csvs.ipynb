# %%
import pandas as pd

df1 = pd.read_csv("cleaned_output_1.csv")
df2 = pd.read_csv("cleaned_output_2.csv")

# Stack / append
merged_df = pd.concat([df1, df2], ignore_index=True)

merged_df.to_csv("merged_profile_scraper.csv", index=False)
merged_df.head()
# Out:
#                                            inputUrl ownerFullName  \
# 0         https://www.instagram.com/yuuhaiofficial/           NaN
# 1  https://www.instagram.com/leadsourcingsolutions/           NaN
# 2               https://www.instagram.com/phi.club/           NaN
# 3              https://www.instagram.com/kaito.dev/           NaN
# 4      https://www.instagram.com/officialfionatran/           NaN
#
#    commentsCount                                        externalUrl  \
# 0            NaN                                                NaN
# 1            NaN             https://www.leadsourcingsolutions.com/
# 2            NaN                         https://linktr.ee/phi.club
# 3            NaN                                http://odysser.com/
# 4            NaN  https://www.officialfionatran.com/blog/just-a-...
#
#    followersCount  followsCount                          fullName  \
# 0         62906.0         129.0                            YUUHAI
# ...
