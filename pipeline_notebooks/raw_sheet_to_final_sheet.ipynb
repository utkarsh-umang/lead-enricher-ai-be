# %%
import asyncio
import re
from google.oauth2 import service_account
from googleapiclient.discovery import build
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import time

# %%
RAW_SHEET_NAME = "Sheet1" 
PROCESSED_SHEET_NAME = "Sheet2"  
CONTENT_DELIMITER = "--- NEXT CONTENT FROM HERE ---"
CATEGORIES = ["ABOUT_US", "EBOOK", "COURSES", "RECENT_BLOG", "TESTIMONIALS", "WEBINAR", "SERVICES", "PODCAST", "SHOP"]
COLUMN_TO_WRITE_URL_TO = {
	"ABOUT_US": "M", "EBOOK": "N", "COURSES": "O", "RECENT_BLOG": "P",
	"TESTIMONIALS": "Q", "WEBINAR": "R", "SERVICES": "S", "PODCAST": "T", "SHOP": "U"
}
EXTRACTION_METADATA_COLUMN = "V"
CATEGORY_THRESHOLDS = {
	"ABOUT_US": 200, "EBOOK": 200, "COURSES": 300, "RECENT_BLOG": 450, 
	"TESTIMONIALS": 100, "WEBINAR": 150, "SERVICES": 150, "PODCAST": 200, "SHOP": 100
}
OPENAI_API_KEY = ""
CREDENTIALS_FILE = '/Users/utkarshumang/Downloads/url-to-email-445616-cebe4868914f.json'
SHEET_URL = "https://docs.google.com/spreadsheets/d/1w1xbupGV4t8qmf58bfCG8tB59FHCLbgY9oOfQpkksS0/edit?gid=0#gid=0" 
PROMPT_TEMPLATES = {
		"RECENT_BLOG": """
You are provided with multiple blog posts. Your task is to evaluate each post based on the following criteria and select the one with the highest total score. Then, output **only** the content text of the selected blog post. Do not include any explanations, scores, rankings, metadata, or additional information.

**Evaluation Criteria:**
1. *Recency*: Score based on how recently the post was published, using the publication date provided.
2. *Relevance to Prospect's Industry*: Score based on how relevant the content is to the specified industry or keywords, using the excerpt provided.
3. *Post Length*: Score based on the word count, with a minimum of 200 words.

**Scoring Guidelines**:
- *Recency*:
	- Within the last month: 10
	- 1-3 months ago: 8
	- 3-6 months ago: 6
	- 6-12 months ago: 4
	- Over 12 months ago: 2
- *Relevance to Prospect's Industry*:
	- Highly relevant (multiple keywords or strong topic alignment): 10
	- Moderately relevant (some keywords or partial alignment): 7
	- Slightly relevant (few keywords or weak alignment): 5
	- Not relevant: 0
- *Post Length*:
	- Less than 200 words: 0
	- 200-500 words: 5
	- 500-1000 words: 7
	- 1000-2000 words: 9
	- 2000+ words: 10

**Final Output**:
- Output **only** the content text of the blog post with the highest total score.
- Do **not** include any explanations, scores, rankings, metadata (e.g., "Content length", "Line count", "Word Count"), or any other information.
- Do **not** mention other posts or provide any additional context.

{content}
"""
}

# %%
# Global rate limiter to track API requests across all categories
class RateLimiter:
    def __init__(self, max_requests_per_minute=60):
        self.max_requests_per_minute = max_requests_per_minute
        self.request_times = []
        
    async def wait_if_needed(self):
        """Wait if we're approaching the rate limit"""
        now = time.time()
        
        # Remove timestamps older than 1 minute
        self.request_times = [t for t in self.request_times if now - t < 60]
        
        # If we're at capacity, wait until we have space
        if len(self.request_times) >= self.max_requests_per_minute:
            oldest = min(self.request_times)
            wait_time = 60 - (now - oldest) + 0.1  # Add a small buffer
            if wait_time > 0:
                print(f"   ⏱️ Rate limit approaching: waiting {wait_time:.2f} seconds")
                await asyncio.sleep(wait_time)
        
        # Add the current request
        self.request_times.append(time.time())

# GoogleSheetsManager class for API interactions
class GoogleSheetsManager:
    def __init__(self, credentials_file):
        print(f"🔧 Initializing GoogleSheetsManager with credentials: {credentials_file}")
        scopes = ['https://www.googleapis.com/auth/spreadsheets']
        creds = service_account.Credentials.from_service_account_file(credentials_file, scopes=scopes)
        self.service = build('sheets', 'v4', credentials=creds)
        print("✅ Google Sheets service initialized successfully")

    def extract_spreadsheet_id(self, sheet_url):
        print(f"🔍 Extracting spreadsheet ID from URL: {sheet_url}")
        pattern = r'/spreadsheets/d/([a-zA-Z0-9-_]+)'
        match = re.search(pattern, sheet_url)
        if match:
            spreadsheet_id = match.group(1)
            print(f"✅ Extracted spreadsheet ID: {spreadsheet_id}")
            return spreadsheet_id
        raise ValueError(f"Invalid Google Sheet URL: {sheet_url}")

# Parse content into pieces based on delimiter and metadata
def parse_content_pieces(content, expected_count, category, row_num):
    print(f"\n📝 Parsing content for {category} (Row {row_num})")
    print(f"   Expected count: {expected_count}")
    print(f"   Content length: {len(content) if content else 0} characters")
    
    if not content or not content.strip():
        print("   ⚠️  No content to parse")
        return []
    
    cleaned_content = content.strip()
    delimiters_to_try = [
        CONTENT_DELIMITER,
        CONTENT_DELIMITER.strip(),
        "-----NEXT CONTENT FROM HERE-----",
        "--- NEXT CONTENT FROM HERE ---"
        "--- --NEXT CONTENT FROM HERE-----",
        "-----NEXT CONTENT FROM HERE--- --",
    ]
    
    pieces = None
    delimiter_used = None
    
    print(f"   🔍 Trying {len(delimiters_to_try)} different delimiters...")
    for i, delimiter in enumerate(delimiters_to_try):
        if delimiter in cleaned_content:
            pieces = cleaned_content.split(delimiter)
            delimiter_used = delimiter
            print(f"   ✅ Found delimiter #{i+1}: '{delimiter[:30]}...'")
            break
    
    if pieces is None:
        print("   ℹ️  No delimiter found, treating as single piece")
        pieces = [cleaned_content]
    else:
        print(f"   📊 Split into {len(pieces)} raw pieces")
    
    cleaned_pieces = [piece.strip() for piece in pieces if piece.strip()]
    print(f"   🧹 After cleaning: {len(cleaned_pieces)} valid pieces")
    
    for i, piece in enumerate(cleaned_pieces):
        print(f"      Piece {i+1}: {len(piece)} chars, {len(piece.split())} words")
    
    if expected_count == 1 and len(cleaned_pieces) == 1:
        print("   ✅ Expected 1, got 1 - returning as is")
        return cleaned_pieces
    elif expected_count > 1:
        if len(cleaned_pieces) >= expected_count:
            result = cleaned_pieces[:expected_count]
            print(f"   ✂️  Taking first {expected_count} pieces")
            return result
        else:
            print(f"   ⚠️  Expected {expected_count}, only got {len(cleaned_pieces)}")
            return cleaned_pieces
    else:
        print(f"   ↩️  Returning all {len(cleaned_pieces)} pieces")
        return cleaned_pieces

# Read and organize data from the input sheet
async def read_data_from_sheet(spreadsheet_id, sheet_mgr, categories):
    print(f"\n📖 Reading data from spreadsheet: {spreadsheet_id}")
    print(f"   Categories to process: {categories}")
    
    category_columns = {cat: COLUMN_TO_WRITE_URL_TO.get(cat.upper()) for cat in categories}
    print(f"   Column mapping: {category_columns}")
    
    if any(col is None for col in category_columns.values()):
        missing = [cat for cat, col in category_columns.items() if col is None]
        print(f"   ❌ Missing columns for categories: {missing}")
        raise ValueError("One or more categories do not have a defined column in COLUMN_TO_WRITE_URL_TO")
    
    metadata_column = EXTRACTION_METADATA_COLUMN
    ranges = [f"{RAW_SHEET_NAME}!{col}2:{col}" for col in category_columns.values()] + [f"{RAW_SHEET_NAME}!{metadata_column}2:{metadata_column}"]
    print(f"   📋 Reading ranges: {ranges}")
    
    try:
        response = await asyncio.to_thread(
            sheet_mgr.service.spreadsheets().values().batchGet(spreadsheetId=spreadsheet_id, ranges=ranges).execute
        )
        print("   ✅ Successfully read data from Google Sheets")
    except Exception as e:
        print(f"   ❌ Failed to read data: {str(e)}")
        raise RuntimeError(f"Failed to read data from spreadsheet {spreadsheet_id}: {str(e)}")
    
    value_ranges = response.get('valueRanges', [])
    print(f"   📊 Got {len(value_ranges)} value ranges")
    
    column_data = {}
    for i, col in enumerate(category_columns.values()):
        column_data[col] = value_ranges[i].get('values', [])
        print(f"   Column {col}: {len(column_data[col])} rows")
    
    column_data[metadata_column] = value_ranges[-1].get('values', [])
    print(f"   Metadata column {metadata_column}: {len(column_data[metadata_column])} rows")
    
    num_rows = max(len(values) for values in column_data.values()) if column_data else 0
    print(f"   📏 Total rows to process: {num_rows}")
    
    data = []
    for i in range(num_rows):
        print(f"\n   🔍 Processing row {i+2}...")
        row_data = {}
        
        # Get metadata
        metadata_value = column_data[metadata_column][i][0] if i < len(column_data[metadata_column]) and column_data[metadata_column][i] else ''
        print(f"      Metadata: '{metadata_value}'")
        
        # Parse category counts
        category_n_dict = {}
        for part in metadata_value.split(','):
            if '=' in part:
                cat, n_str = part.split('=', 1)
                try:
                    n = int(n_str.strip())
                    category_n_dict[cat.strip().upper()] = n
                    print(f"      Found: {cat.strip().upper()} = {n}")
                except ValueError:
                    print(f"      ⚠️  Invalid count for: {part}")
                    pass
        
        print(f"      Category counts: {category_n_dict}")
        
        # Process each category
        for category in categories:
            category_upper = category.upper()
            print(f"      🔍 Checking category: {category_upper}")
            
            if category_upper in category_n_dict and category_n_dict[category_upper] > 0:
                print(f"         ✅ Count > 0, processing...")
                col = category_columns[category]
                content = column_data[col][i][0] if i < len(column_data[col]) and column_data[col][i] else ''
                expected_count = category_n_dict[category_upper]
                
                print(f"         Content preview: '{content[:100]}...' ({len(content)} chars)")
                
                parsed_pieces = parse_content_pieces(content, expected_count, category, i+2)
                if parsed_pieces:
                    row_data[category] = parsed_pieces
                    print(f"         ✅ Added {len(parsed_pieces)} pieces to row data")
                else:
                    print(f"         ⚠️  No valid pieces found")
            else:
                print(f"         ❌ Skipping (count = {category_n_dict.get(category_upper, 0)})")
        
        data.append(row_data)
        print(f"      Row {i+2} final data: {list(row_data.keys())}")
    
    print(f"✅ Data reading complete. Processed {len(data)} rows")
    return data

# Format RECENT_BLOG content for AI processing
def explore_all_content1(data, row_number, category):
    print(f"\n🤖 Formatting content for AI processing...")
    print(f"   Row: {row_number}, Category: {category}")
    
    try:
        row_data = data[row_number - 2]
        print(f"   Row data keys: {list(row_data.keys())}")
        
        if category in row_data:
            pieces = row_data[category]
            print(f"   Found {len(pieces)} pieces to format")
            
            output = []
            for idx, content in enumerate(pieces, start=1):
                print(f"   Formatting piece {idx}: {len(content)} chars")
                output.append(f"*Blog Post {idx}*:")
                output.append(content)
                output.append("")
                output.append(f"Content length: {len(content)} characters")
                output.append(f"Line count: {len(content.splitlines())}")
                output.append(f"Word Count: {len(content.split())}")
            
            formatted_output = "\n".join(output)
            print(f"   ✅ Formatted output: {len(formatted_output)} total chars")
            return formatted_output
        else:
            error_msg = f"Error: Category '{category}' not found in row {row_number}."
            print(f"   ❌ {error_msg}")
            return error_msg
    except IndexError:
        error_msg = f"Error: Row {row_number} not found. Available rows: 2 to {len(data) + 1}"
        print(f"   ❌ {error_msg}")
        return error_msg

# Set up LangChain pipeline for AI processing
def create_chain(category):
    print(f"🔗 Creating LangChain pipeline for category: {category}")
    
    if category not in PROMPT_TEMPLATES:
        error_msg = f"No prompt defined for category {category}"
        print(f"   ❌ {error_msg}")
        raise ValueError(error_msg)
    
    prompt = PromptTemplate(
        input_variables=["content"],
        template=PROMPT_TEMPLATES[category]
    )
    
    print(f"   📝 Using prompt template for {category}")
    print(f"   🤖 Initializing ChatOpenAI with GPT-4")
    
    llm = ChatOpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
    chain = prompt | llm | StrOutputParser()
    
    print(f"   ✅ Chain created successfully")
    return chain

# Process RECENT_BLOG row with AI
async def process_row_with_langchain(content_output, category):
    print(f"\n🚀 Processing with AI (LangChain)...")
    print(f"   Category: {category}")
    print(f"   Input length: {len(content_output)} characters")
    
    chain = create_chain(category)
    
    if not content_output.strip() or "Error:" in content_output:
        error_msg = f"No valid content provided for {category}"
        print(f"   ❌ {error_msg}")
        return error_msg
    
    try:
        print("   🔄 Sending to AI...")
        response = await chain.ainvoke({"content": content_output})
        print(f"   ✅ AI processing successful!")
        print(f"   📤 Response length: {len(response)} characters")
        print(f"   📤 Response preview: '{response[:200]}...'")
        return response
    except Exception as e:
        error_msg = f"Error processing row for {category}: {str(e)}"
        print(f"   ❌ {error_msg}")
        return f"Error processing row for {category}"

# Modified write_batch function with improved rate limiting
async def write_batch_with_rate_limit(sheet_mgr, spreadsheet_id, range_name, values, batch_num, category, 
                                     max_retries=3, rate_limiter=None):
    """Write a batch to Google Sheets with retry logic and rate limiting."""
    print(f"\n   📤 Writing batch #{batch_num} to sheet range: {range_name}")
    print(f"   📊 Writing {len(values)} values")
    
    retry_count = 0
    backoff_time = 1  # Start with 1 second
    
    while retry_count <= max_retries:
        try:
            # Check rate limits before making the request
            if rate_limiter:
                await rate_limiter.wait_if_needed()
            
            sheet_mgr.service.spreadsheets().values().update(
                spreadsheetId=spreadsheet_id,
                range=range_name,
                valueInputOption='RAW',
                body={'values': values}
            ).execute()
            
            print(f"   ✅ Successfully wrote batch #{batch_num} for {category}")
            return True
            
        except Exception as e:
            retry_count += 1
            is_quota_error = "quota" in str(e).lower() or "rate" in str(e).lower()
            
            if is_quota_error and retry_count <= max_retries:
                # Exponential backoff for quota errors
                print(f"   ⚠️ Rate limit exceeded on attempt {retry_count}/{max_retries}")
                print(f"   ⏱️ Backing off for {backoff_time} seconds...")
                await asyncio.sleep(backoff_time)
                backoff_time *= 2  # Exponential backoff
                print(f"   🔄 Retrying...")
            else:
                # Other error or max retries reached
                print(f"   ❌ Failed to write batch #{batch_num} for {category}: {str(e)}")
                if retry_count > max_retries:
                    print(f"   ❌ Max retries ({max_retries}) exceeded")
                return False
    
    return False

# Process a category column according to the algorithm
async def process_category(data, category, sheet_mgr, spreadsheet_id, start_row=2, batch_size=5, max_retries=3, rate_limiter=None):
    print(f"\n🏭 Processing category: {category}")
    print(f"   Starting from row: {start_row}")
    print(f"   Batch size: {batch_size}")
    
    column = COLUMN_TO_WRITE_URL_TO[category.upper()]
    print(f"   Target column: {column}")
    
    values = []
    current_batch = 0
    
    # Calculate the range of rows to process based on start_row
    data_start_idx = start_row - 2  # Convert sheet row to data array index
    end_row = len(data) + 2
    
    print(f"   Processing sheet rows {start_row} to {end_row-1}")
    print(f"   Data array indices {data_start_idx} to {len(data)-1}")
    
    for row_idx in range(start_row, end_row):
        data_idx = row_idx - 2  # Convert sheet row to data array index
        
        # Check if we have data for this row
        if data_idx >= len(data):
            print(f"      ⚠️ Row {row_idx} exceeds available data, stopping")
            break
            
        print(f"\n   📋 Processing row {row_idx} (data index {data_idx})...")
        row_data = data[data_idx]
        pieces = row_data.get(category, [])
        
        print(f"      Found {len(pieces)} pieces for {category}")
        
        # [existing processing logic remains the same]
        if not pieces:
            output = "no content"
            print(f"      ❌ No pieces found -> '{output}'")
        elif len(pieces) == 1:
            output = pieces[0]
            print(f"      📋 Single piece -> copying directly ({len(output)} chars)")
        else:
            print(f"      🔄 Multiple pieces ({len(pieces)}) - applying processing logic...")
            
            if category == "RECENT_BLOG":
                print(f"         🤖 RECENT_BLOG category -> AI processing")
                content_output = explore_all_content1(data, row_idx, category)
                
                if "Error:" in content_output:
                    output = "No valid content provided"
                    print(f"         ❌ Error in content formatting -> '{output}'")
                else:
                    print(f"         🚀 Sending to AI processing...")
                    output = await process_row_with_langchain(content_output, category)
                    print(f"         ✅ AI processing complete")
            else:
                # Non-blog categories logic
                print(f"         📏 Non-blog category -> length-based selection")
                threshold = CATEGORY_THRESHOLDS.get(category.upper(), 0)
                print(f"         📊 Word threshold: {threshold}")
                
                candidates = [p for p in pieces if len(p.split()) >= threshold]
                print(f"         🎯 Candidates meeting threshold: {len(candidates)}")
                
                if candidates:
                    output = max(candidates, key=lambda p: len(p.split()))
                    print(f"         ✅ Selected longest candidate: {len(output.split())} words")
                else:
                    output = max(pieces, key=lambda p: len(p.split()))
                    print(f"         ⚠️  No candidates met threshold, selected longest: {len(output.split())} words")
        
        values.append([output])
        print(f"      ✅ Row {row_idx} output: {len(output)} chars")
        
        # Check if batch is complete
        if len(values) >= batch_size:
            # Calculate the range for the current batch
            batch_start_row = start_row + current_batch * batch_size
            batch_end_row = batch_start_row + len(values) - 1
            batch_range = f"{PROCESSED_SHEET_NAME}!{column}{batch_start_row}:{column}{batch_end_row}"
            
            print(f"      📤 Writing batch to range: {batch_range}")
            
            # Write the current batch with retry and rate limiting
            await write_batch_with_rate_limit(
                sheet_mgr=sheet_mgr,
                spreadsheet_id=spreadsheet_id,
                range_name=batch_range,
                values=values,
                batch_num=current_batch+1,
                category=category,
                max_retries=max_retries,
                rate_limiter=rate_limiter
            )
            
            # Reset for next batch
            values = []
            current_batch += 1
    
    # Write any remaining rows
    if values:
        batch_start_row = start_row + current_batch * batch_size
        batch_end_row = batch_start_row + len(values) - 1
        batch_range = f"{PROCESSED_SHEET_NAME}!{column}{batch_start_row}:{column}{batch_end_row}"
        
        print(f"   📤 Writing final batch to range: {batch_range}")
        
        await write_batch_with_rate_limit(
            sheet_mgr=sheet_mgr,
            spreadsheet_id=spreadsheet_id,
            range_name=batch_range,
            values=values,
            batch_num="final",
            category=category,
            max_retries=max_retries,
            rate_limiter=rate_limiter
        )

# %%
async def main(regular_batch_size=100, blog_batch_size=5, max_retries=3, start_row=2):
    print("🚀 Starting Content Processing Pipeline")
    print("=" * 50)
    print(f"Regular batch size: {regular_batch_size}, Blog batch size: {blog_batch_size}")
    print(f"Max retries: {max_retries}")
    print(f"Starting from row: {start_row}")
    
    # Create a global rate limiter (target 50 requests/min to stay comfortably under the 60/min limit)
    rate_limiter = RateLimiter(max_requests_per_minute=50)
    
    try:
        print("\n📋 Step 1: Initialize Google Sheets Manager")
        sheet_mgr = GoogleSheetsManager(CREDENTIALS_FILE)
        
        print("\n📋 Step 2: Extract Spreadsheet ID")
        spreadsheet_id = sheet_mgr.extract_spreadsheet_id(SHEET_URL)
        
        print("\n📋 Step 3: Read Data from Sheet")
        data = await read_data_from_sheet(spreadsheet_id, sheet_mgr, CATEGORIES)
        
        # Validate start_row
        max_available_row = len(data) + 1  # +1 because data starts from row 2
        if start_row > max_available_row:
            print(f"❌ Error: start_row ({start_row}) exceeds available data (max row: {max_available_row})")
            return
        
        print(f"\n📋 Step 4: Process Categories ({len(CATEGORIES)} total)")
        print(f"   Available data rows: 2 to {max_available_row}")
        print(f"   Processing rows: {start_row} to {max_available_row}")
        
        # Separate categories into regular and blog
        regular_categories = [cat for cat in CATEGORIES if cat != "RECENT_BLOG"]
        blog_category = "RECENT_BLOG" if "RECENT_BLOG" in CATEGORIES else None
        
        # Process regular categories first with larger batch size
        for i, category in enumerate(regular_categories, 1):
            print(f"\n🔄 Processing regular category {i}/{len(regular_categories)}: {category}")
            await process_category(
                data, 
                category, 
                sheet_mgr, 
                spreadsheet_id, 
                start_row=start_row,
                batch_size=regular_batch_size, 
                max_retries=max_retries,
                rate_limiter=rate_limiter
            )
            print(f"✅ Completed regular category: {category}")
        
        # Process blog category last with smaller batch size
        if blog_category:
            print(f"\n🔄 Processing blog category: {blog_category} (with smaller batch size)")
            await process_category(
                data, 
                blog_category, 
                sheet_mgr, 
                spreadsheet_id, 
                start_row=start_row,
                batch_size=blog_batch_size, 
                max_retries=max_retries,
                rate_limiter=rate_limiter
            )
            print(f"✅ Completed blog category: {blog_category}")
        
        print("\n🎉 Pipeline completed successfully!")
        
    except Exception as e:
        print(f"\n💥 Pipeline failed with error: {str(e)}")
        import traceback
        print("📋 Full traceback:")
        traceback.print_exc()

# %%
await main(regular_batch_size=100, blog_batch_size=5, start_row=2)
# Out:
# 🚀 Starting Content Processing Pipeline
# ==================================================
# Regular batch size: 100, Blog batch size: 5
# Max retries: 3
# Starting from row: 2
#
# 📋 Step 1: Initialize Google Sheets Manager
# 🔧 Initializing GoogleSheetsManager with credentials: data/url-to-email-445616-cebe4868914f.json
# ✅ Google Sheets service initialized successfully
#
# 📋 Step 2: Extract Spreadsheet ID
# 🔍 Extracting spreadsheet ID from URL: https://docs.google.com/spreadsheets/d/1FFZ0c_SgpAcYgLU2gtVx4IFCFhOcQqf8DRdsarhCd_I/edit?gid=0#gid=0
# ✅ Extracted spreadsheet ID: 1FFZ0c_SgpAcYgLU2gtVx4IFCFhOcQqf8DRdsarhCd_I
#
# 📋 Step 3: Read Data from Sheet
#
# 📖 Reading data from spreadsheet: 1FFZ0c_SgpAcYgLU2gtVx4IFCFhOcQqf8DRdsarhCd_I
#    Categories to process: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Column mapping: {'ABOUT_US': 'M', 'EBOOK': 'N', 'COURSES': 'O', 'RECENT_BLOG': 'P', 'TESTIMONIALS': 'Q', 'WEBINAR': 'R', 'SERVICES': 'S', 'PODCAST': 'T', 'SHOP': 'U'}
#    📋 Reading ranges: ['Sheet1!M2:M', 'Sheet1!N2:N', 'Sheet1!O2:O', 'Sheet1!P2:P', 'Sheet1!Q2:Q', 'Sheet1!R2:R', 'Sheet1!S2:S', 'Sheet1!T2:T', 'Sheet1!U2:U', 'Sheet1!V2:V']
#    ✅ Successfully read data from Google Sheets
#    📊 Got 10 value ranges
#    Column M: 352 rows
#    Column N: 352 rows
#    Column O: 352 rows
#    Column P: 352 rows
#    Column Q: 352 rows
#    Column R: 352 rows
#    Column S: 352 rows
#    Column T: 352 rows
#    Column U: 352 rows
#    Metadata column V: 352 rows
#    📏 Total rows to process: 352
#
#    🔍 Processing row 2...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=3,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 3
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 3, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: '3
# /
# 3
# HOME
# TECHNICAL SERVICES
# TELECOMMUNICATIONS
# SECURITY SERVICES
# NUCLEAR SERVICES
# CONTACT US
# Decom...' (1556 chars)
#
# 📝 Parsing content for SERVICES (Row 2)
#    Expected count: 3
#    Content length: 1556 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 3 raw pieces
#    🧹 After cleaning: 3 valid pieces
#       Piece 1: 518 chars, 63 words
#       Piece 2: 486 chars, 65 words
#       Piece 3: 488 chars, 62 words
#    ✂️  Taking first 3 pieces
#          ✅ Added 3 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 2 final data: ['SERVICES']
#
#    🔍 Processing row 3...
#       Metadata: 'ABOUT_US=1,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=7,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 1
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 7
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 1, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 7, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'Home
# >
# Solutions
# Storage Backup Disaster Recovery
# Networking & Wireless
# Infrastructure & Cloud
# Secur...' (362 chars)
#
# 📝 Parsing content for ABOUT_US (Row 3)
#    Expected count: 1
#    Content length: 362 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 362 chars, 51 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Home
# >
# Solutions
# Storage Backup Disaster Recovery
# Networking & Wireless
# Infrastructure & Cloud
# Secur...' (10934 chars)
#
# 📝 Parsing content for SERVICES (Row 3)
#    Expected count: 7
#    Content length: 10934 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 7 raw pieces
#    🧹 After cleaning: 7 valid pieces
#       Piece 1: 1049 chars, 155 words
#       Piece 2: 1135 chars, 170 words
#       Piece 3: 4400 chars, 718 words
#       Piece 4: 1346 chars, 174 words
#       Piece 5: 1552 chars, 188 words
#       Piece 6: 671 chars, 88 words
#       Piece 7: 589 chars, 78 words
#    ✂️  Taking first 7 pieces
#          ✅ Added 7 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 3 final data: ['ABOUT_US', 'SERVICES']
#
#    🔍 Processing row 4...
#       Metadata: 'ABOUT_US=3,EBOOK=1,COURSES=2,RECENT_BLOG=10,TESTIMONIALS=2,WEBINAR=10,SERVICES=1,PODCAST=0,SHOP=2'
#       Found: ABOUT_US = 3
#       Found: EBOOK = 1
#       Found: COURSES = 2
#       Found: RECENT_BLOG = 10
#       Found: TESTIMONIALS = 2
#       Found: WEBINAR = 10
#       Found: SERVICES = 1
#       Found: PODCAST = 0
#       Found: SHOP = 2
#       Category counts: {'ABOUT_US': 3, 'EBOOK': 1, 'COURSES': 2, 'RECENT_BLOG': 10, 'TESTIMONIALS': 2, 'WEBINAR': 10, 'SERVICES': 1, 'PODCAST': 0, 'SHOP': 2}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'ABOUT US
# At LiveWell Behavioral Health, we are passionate about helping people get healthy, stay hea...' (11755 chars)
#
# 📝 Parsing content for ABOUT_US (Row 4)
#    Expected count: 3
#    Content length: 11755 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 3 raw pieces
#    🧹 After cleaning: 3 valid pieces
#       Piece 1: 1456 chars, 222 words
#       Piece 2: 2677 chars, 458 words
#       Piece 3: 7558 chars, 1309 words
#    ✂️  Taking first 3 pieces
#          ✅ Added 3 pieces to row data
#       🔍 Checking category: EBOOK
#          ✅ Count > 0, processing...
#          Content preview: 'Resources
# Podcasts, blogs, and teaching videos to help you live well.
# All
# Podcast
# Teaching
# Coaching
# ...' (2229 chars)
#
# 📝 Parsing content for EBOOK (Row 4)
#    Expected count: 1
#    Content length: 2229 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 2229 chars, 378 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Clinical Program Director
# Clinical Program Director Wanted: Shape the Future of Mental Health Care!
# ...' (12335 chars)
#
# 📝 Parsing content for COURSES (Row 4)
#    Expected count: 2
#    Content length: 12335 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 5284 chars, 718 words
#       Piece 2: 7019 chars, 1164 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'LiveWell
# Feb 11, 2019 9:52:43 AM
# 7
#  min read
# Relax
# Riding a motorcycle at 110 mph down the interstat...' (46994 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 4)
#    Expected count: 10
#    Content length: 46994 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 6010 chars, 1013 words
#       Piece 2: 5295 chars, 874 words
#       Piece 3: 1314 chars, 243 words
#       Piece 4: 3298 chars, 599 words
#       Piece 5: 6630 chars, 1169 words
#       Piece 6: 6386 chars, 1077 words
#       Piece 7: 6301 chars, 1105 words
#       Piece 8: 5300 chars, 926 words
#       Piece 9: 6204 chars, 1111 words
#    ⚠️  Expected 10, only got 9
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ✅ Count > 0, processing...
#          Content preview: 'Neurofeedback
# A non-invasive approach to maximizing your brain function.
# Discover the transformative...' (13085 chars)
#
# 📝 Parsing content for TESTIMONIALS (Row 4)
#    Expected count: 2
#    Content length: 13085 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 2813 chars, 396 words
#       Piece 2: 10240 chars, 1672 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'LiveWell
# Feb 11, 2019 9:52:43 AM
# 7
#  min read
# Relax
# Riding a motorcycle at 110 mph down the interstat...' (46994 chars)
#
# 📝 Parsing content for WEBINAR (Row 4)
#    Expected count: 10
#    Content length: 46994 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 6010 chars, 1013 words
#       Piece 2: 5295 chars, 874 words
#       Piece 3: 1314 chars, 243 words
#       Piece 4: 3298 chars, 599 words
#       Piece 5: 6630 chars, 1169 words
#       Piece 6: 6386 chars, 1077 words
#       Piece 7: 6301 chars, 1105 words
#       Piece 8: 5300 chars, 926 words
#       Piece 9: 6204 chars, 1111 words
#    ⚠️  Expected 10, only got 9
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Dr. Trevor
# 8 min read
# Conflict Resolution: Better Strategies for Better Results
# Research reveals tha...' (10240 chars)
#
# 📝 Parsing content for SERVICES (Row 4)
#    Expected count: 1
#    Content length: 10240 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 10240 chars, 1672 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'Betsy Carter
# MS, LMHC, MCAP
# Elizabeth Carter graduated with her Bachelors Degree in Sociology in 198...' (7979 chars)
#
# 📝 Parsing content for SHOP (Row 4)
#    Expected count: 2
#    Content length: 7979 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 629 chars, 87 words
#       Piece 2: 7318 chars, 1240 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       Row 4 final data: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'SHOP']
#
#    🔍 Processing row 5...
#       Metadata: 'ABOUT_US=2,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 2
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 2, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'ABOUT
# EVOLUTION DEVELOPMENT GROUP
# Evolution Development Group is a small, privately-owned consulting...' (1164 chars)
#
# 📝 Parsing content for ABOUT_US (Row 5)
#    Expected count: 2
#    Content length: 1164 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 365 chars, 52 words
#       Piece 2: 767 chars, 130 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 5 final data: ['ABOUT_US']
#
#    🔍 Processing row 6...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 6 final data: []
#
#    🔍 Processing row 7...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 7 final data: []
#
#    🔍 Processing row 8...
#       Metadata: 'ABOUT_US=1,EBOOK=1,COURSES=1,RECENT_BLOG=2,TESTIMONIALS=0,WEBINAR=1,SERVICES=2,PODCAST=0,SHOP=10'
#       Found: ABOUT_US = 1
#       Found: EBOOK = 1
#       Found: COURSES = 1
#       Found: RECENT_BLOG = 2
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 1
#       Found: SERVICES = 2
#       Found: PODCAST = 0
#       Found: SHOP = 10
#       Category counts: {'ABOUT_US': 1, 'EBOOK': 1, 'COURSES': 1, 'RECENT_BLOG': 2, 'TESTIMONIALS': 0, 'WEBINAR': 1, 'SERVICES': 2, 'PODCAST': 0, 'SHOP': 10}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'About Us
# ABOUT ICETRO
# Since its inception in 1981, ICETRO has been a global industry leader as a com...' (2819 chars)
#
# 📝 Parsing content for ABOUT_US (Row 8)
#    Expected count: 1
#    Content length: 2819 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 2819 chars, 440 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: EBOOK
#          ✅ Count > 0, processing...
#          Content preview: 'Resource Library
# Library
# Spec Sheets
# User Manuals
# Product Literature
# Price Lists
# Service Manuals
# Par...' (286 chars)
#
# 📝 Parsing content for EBOOK (Row 8)
#    Expected count: 1
#    Content length: 286 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 286 chars, 41 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Co-op Program
# The Best Ice Machines in the World
# The Icetro Co-op Program works as follows:
# Co-op fu...' (1595 chars)
#
# 📝 Parsing content for COURSES (Row 8)
#    Expected count: 1
#    Content length: 1595 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 1595 chars, 276 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'NEWSFEED
# Category Archives:
# Icetroamerica Blog
# Icetro's Unique Sales Points (USP)
# Icetroamerica Blog...' (964 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 8)
#    Expected count: 2
#    Content length: 964 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 485 chars, 69 words
#       Piece 2: 447 chars, 65 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Warranty Registration
# For Icetro Ice, Slush, and Soft serve machines
# NOTE: Do not use this page to r...' (2031 chars)
#
# 📝 Parsing content for WEBINAR (Row 8)
#    Expected count: 1
#    Content length: 2031 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 2031 chars, 243 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Technical Support
# This form will be used by customers and service agents to send requests for suppor...' (6404 chars)
#
# 📝 Parsing content for SERVICES (Row 8)
#    Expected count: 2
#    Content length: 6404 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 3970 chars, 557 words
#       Piece 2: 2402 chars, 378 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'Sort by Equipment Type
# Modular Ice Machines
# Undercounter Ice machines
# Ice Dispensers
# Slush
# Ice Stora...' (26669 chars)
#
# 📝 Parsing content for SHOP (Row 8)
#    Expected count: 10
#    Content length: 26669 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 391 chars, 55 words
#       Piece 2: 2897 chars, 450 words
#       Piece 3: 2896 chars, 450 words
#       Piece 4: 3110 chars, 480 words
#       Piece 5: 3109 chars, 480 words
#       Piece 6: 2896 chars, 450 words
#       Piece 7: 2897 chars, 450 words
#       Piece 8: 2247 chars, 336 words
#       Piece 9: 3106 chars, 479 words
#       Piece 10: 2832 chars, 442 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       Row 8 final data: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'SHOP']
#
#    🔍 Processing row 9...
#       Metadata: 'ABOUT_US=5,EBOOK=10,COURSES=4,RECENT_BLOG=10,TESTIMONIALS=3,WEBINAR=10,SERVICES=10,PODCAST=2,SHOP=10'
#       Found: ABOUT_US = 5
#       Found: EBOOK = 10
#       Found: COURSES = 4
#       Found: RECENT_BLOG = 10
#       Found: TESTIMONIALS = 3
#       Found: WEBINAR = 10
#       Found: SERVICES = 10
#       Found: PODCAST = 2
#       Found: SHOP = 10
#       Category counts: {'ABOUT_US': 5, 'EBOOK': 10, 'COURSES': 4, 'RECENT_BLOG': 10, 'TESTIMONIALS': 3, 'WEBINAR': 10, 'SERVICES': 10, 'PODCAST': 2, 'SHOP': 10}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'Electronic Support Systems (ESS) is a manufacturer’s representative company offering a complete line...' (8421 chars)
#
# 📝 Parsing content for ABOUT_US (Row 9)
#    Expected count: 5
#    Content length: 8421 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 5 raw pieces
#    🧹 After cleaning: 5 valid pieces
#       Piece 1: 1720 chars, 235 words
#       Piece 2: 504 chars, 70 words
#       Piece 3: 3217 chars, 435 words
#       Piece 4: 1204 chars, 174 words
#       Piece 5: 1648 chars, 234 words
#    ✂️  Taking first 5 pieces
#          ✅ Added 5 pieces to row data
#       🔍 Checking category: EBOOK
#          ✅ Count > 0, processing...
#          Content preview: 'Application Solutions
# Bundled solutions of products by application.
# Edge Small
# Edge Medium
# Edge Larg...' (17193 chars)
#
# 📝 Parsing content for EBOOK (Row 9)
#    Expected count: 10
#    Content length: 17193 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 540 chars, 75 words
#       Piece 2: 6969 chars, 1068 words
#       Piece 3: 3683 chars, 761 words
#       Piece 4: 102 chars, 14 words
#       Piece 5: 165 chars, 22 words
#       Piece 6: 1001 chars, 124 words
#       Piece 7: 232 chars, 35 words
#       Piece 8: 1586 chars, 236 words
#       Piece 9: 2338 chars, 341 words
#       Piece 10: 289 chars, 35 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Arc flash incidents are highly concentrated radiant thermal energy resulting from an arcing fault be...' (16735 chars)
#
# 📝 Parsing content for COURSES (Row 9)
#    Expected count: 4
#    Content length: 16735 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 4 raw pieces
#    🧹 After cleaning: 4 valid pieces
#       Piece 1: 10185 chars, 1436 words
#       Piece 2: 3413 chars, 452 words
#       Piece 3: 1393 chars, 173 words
#       Piece 4: 1648 chars, 234 words
#    ✂️  Taking first 4 pieces
#          ✅ Added 4 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'January 11, 2021
# Electronic Support Systems (ESS) is pleased to announce the retirement of Ted Meyer...' (18396 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 9)
#    Expected count: 10
#    Content length: 18396 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 2586 chars, 418 words
#       Piece 2: 1130 chars, 166 words
#       Piece 3: 948 chars, 144 words
#       Piece 4: 3547 chars, 515 words
#       Piece 5: 1486 chars, 207 words
#       Piece 6: 1115 chars, 193 words
#       Piece 7: 2748 chars, 357 words
#       Piece 8: 1985 chars, 286 words
#       Piece 9: 1341 chars, 179 words
#       Piece 10: 1222 chars, 183 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ✅ Count > 0, processing...
#          Content preview: 'Background
# A local American multinational financial services company achieves success in using Verti...' (6790 chars)
#
# 📝 Parsing content for TESTIMONIALS (Row 9)
#    Expected count: 3
#    Content length: 6790 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 3 raw pieces
#    🧹 After cleaning: 3 valid pieces
#       Piece 1: 4163 chars, 598 words
#       Piece 2: 1341 chars, 179 words
#       Piece 3: 1222 chars, 183 words
#    ✂️  Taking first 3 pieces
#          ✅ Added 3 pieces to row data
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Downtime in a data center that supports business-critical operations is not an option. While Liebert...' (26283 chars)
#
# 📝 Parsing content for WEBINAR (Row 9)
#    Expected count: 10
#    Content length: 26283 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 2936 chars, 420 words
#       Piece 2: 4774 chars, 674 words
#       Piece 3: 2103 chars, 311 words
#       Piece 4: 1681 chars, 253 words
#       Piece 5: 4144 chars, 574 words
#       Piece 6: 4076 chars, 584 words
#       Piece 7: 2144 chars, 291 words
#       Piece 8: 1043 chars, 144 words
#       Piece 9: 1678 chars, 230 words
#       Piece 10: 1416 chars, 200 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'view product gallery
# The Albér Battery Xplorer has an intuitive user interface permitting easy revie...' (15940 chars)
#
# 📝 Parsing content for SERVICES (Row 9)
#    Expected count: 10
#    Content length: 15940 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 1279 chars, 183 words
#       Piece 2: 1652 chars, 246 words
#       Piece 3: 1792 chars, 280 words
#       Piece 4: 1156 chars, 184 words
#       Piece 5: 2307 chars, 368 words
#       Piece 6: 1978 chars, 303 words
#       Piece 7: 1314 chars, 199 words
#       Piece 8: 1419 chars, 207 words
#       Piece 9: 1605 chars, 261 words
#       Piece 10: 1150 chars, 186 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: PODCAST
#          ✅ Count > 0, processing...
#          Content preview: 'view product gallery
# view product gallery
# view product gallery
# view product gallery
# The NetSure RDB ...' (1873 chars)
#
# 📝 Parsing content for PODCAST (Row 9)
#    Expected count: 2
#    Content length: 1873 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 825 chars, 133 words
#       Piece 2: 1016 chars, 164 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'Critical Power
# Vertiv, Vycon, PQI, and ASCO's reliable and efficient products that work together to ...' (8145 chars)
#
# 📝 Parsing content for SHOP (Row 9)
#    Expected count: 10
#    Content length: 8145 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 1093 chars, 147 words
#       Piece 2: 737 chars, 100 words
#       Piece 3: 545 chars, 74 words
#       Piece 4: 472 chars, 60 words
#       Piece 5: 434 chars, 58 words
#       Piece 6: 2666 chars, 383 words
#       Piece 7: 360 chars, 68 words
#       Piece 8: 365 chars, 56 words
#       Piece 9: 916 chars, 127 words
#       Piece 10: 269 chars, 34 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       Row 9 final data: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#
#    🔍 Processing row 10...
#       Metadata: 'ABOUT_US=1,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=1,WEBINAR=0,SERVICES=9,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 1
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 1
#       Found: WEBINAR = 0
#       Found: SERVICES = 9
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 1, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 1, 'WEBINAR': 0, 'SERVICES': 9, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'info@proact.gr
# Home
# About Us
# Services
# Machinery Safety Services
# Explosion Protection (ATEX)
# HAZOP, L...' (2370 chars)
#
# 📝 Parsing content for ABOUT_US (Row 10)
#    Expected count: 1
#    Content length: 2370 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 2370 chars, 347 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ✅ Count > 0, processing...
#          Content preview: 'info@proact.gr
# Home
# About Us
# Services
# Machinery Safety Services
# Explosion Protection (ATEX)
# HAZOP, L...' (780 chars)
#
# 📝 Parsing content for TESTIMONIALS (Row 10)
#    Expected count: 1
#    Content length: 780 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 780 chars, 107 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'info@proact.gr
# Home
# About Us
# Services
# Machinery Safety Services
# Explosion Protection (ATEX)
# HAZOP, L...' (31287 chars)
#
# 📝 Parsing content for SERVICES (Row 10)
#    Expected count: 9
#    Content length: 31287 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 6058 chars, 848 words
#       Piece 2: 4772 chars, 686 words
#       Piece 3: 2534 chars, 352 words
#       Piece 4: 1553 chars, 209 words
#       Piece 5: 3201 chars, 453 words
#       Piece 6: 4695 chars, 657 words
#       Piece 7: 2806 chars, 393 words
#       Piece 8: 4394 chars, 626 words
#       Piece 9: 1018 chars, 143 words
#    ✂️  Taking first 9 pieces
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 10 final data: ['ABOUT_US', 'TESTIMONIALS', 'SERVICES']
#
#    🔍 Processing row 11...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 11 final data: []
#
#    🔍 Processing row 12...
#       Metadata: 'ABOUT_US=4,EBOOK=1,COURSES=2,RECENT_BLOG=1,TESTIMONIALS=0,WEBINAR=10,SERVICES=9,PODCAST=5,SHOP=10'
#       Found: ABOUT_US = 4
#       Found: EBOOK = 1
#       Found: COURSES = 2
#       Found: RECENT_BLOG = 1
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 10
#       Found: SERVICES = 9
#       Found: PODCAST = 5
#       Found: SHOP = 10
#       Category counts: {'ABOUT_US': 4, 'EBOOK': 1, 'COURSES': 2, 'RECENT_BLOG': 1, 'TESTIMONIALS': 0, 'WEBINAR': 10, 'SERVICES': 9, 'PODCAST': 5, 'SHOP': 10}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'About Us
# Company Vision
# Careers
# Delivering Enterprise Service Management (ESM) solutions in North Am...' (4375 chars)
#
# 📝 Parsing content for ABOUT_US (Row 12)
#    Expected count: 4
#    Content length: 4375 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 4 raw pieces
#    🧹 After cleaning: 4 valid pieces
#       Piece 1: 1175 chars, 177 words
#       Piece 2: 973 chars, 146 words
#       Piece 3: 325 chars, 51 words
#       Piece 4: 1806 chars, 256 words
#    ✂️  Taking first 4 pieces
#          ✅ Added 4 pieces to row data
#       🔍 Checking category: EBOOK
#          ✅ Count > 0, processing...
#          Content preview: 'Wednesday, November 8, 2023
# IT Asset Management (ITAM) is a crucial function that helps organization...' (591 chars)
#
# 📝 Parsing content for EBOOK (Row 12)
#    Expected count: 1
#    Content length: 591 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 591 chars, 87 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'ComAround Knowledge Management Software
# ComAround’s Knowledge Management software enables self-servi...' (2541 chars)
#
# 📝 Parsing content for COURSES (Row 12)
#    Expected count: 2
#    Content length: 2541 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 1238 chars, 187 words
#       Piece 2: 1271 chars, 190 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'AVAILABLE ON DEMAND
# Express OneBot Webinar – Add a Bot to Your Cherwell Deployment!
# A Smarter Way to...' (948 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 12)
#    Expected count: 1
#    Content length: 948 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 948 chars, 152 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Watch On-Demand
# Invitation from Ivanti & Cherwell:
# By bringing Cherwell into the Ivanti portfolio, w...' (9548 chars)
#
# 📝 Parsing content for WEBINAR (Row 12)
#    Expected count: 10
#    Content length: 9548 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 940 chars, 138 words
#       Piece 2: 436 chars, 71 words
#       Piece 3: 436 chars, 71 words
#       Piece 4: 948 chars, 152 words
#       Piece 5: 226 chars, 36 words
#       Piece 6: 2069 chars, 300 words
#       Piece 7: 225 chars, 28 words
#       Piece 8: 948 chars, 152 words
#       Piece 9: 1700 chars, 251 words
#       Piece 10: 1332 chars, 195 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Microsoft Teams Integration mApp
# Avante offers a Microsoft Teams Integration mApp(r) that enables st...' (18582 chars)
#
# 📝 Parsing content for SERVICES (Row 12)
#    Expected count: 9
#    Content length: 18582 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 1188 chars, 178 words
#       Piece 2: 7075 chars, 1027 words
#       Piece 3: 1157 chars, 154 words
#       Piece 4: 907 chars, 118 words
#       Piece 5: 1648 chars, 232 words
#       Piece 6: 1273 chars, 174 words
#       Piece 7: 1027 chars, 143 words
#       Piece 8: 1998 chars, 284 words
#       Piece 9: 2053 chars, 266 words
#    ✂️  Taking first 9 pieces
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: PODCAST
#          ✅ Count > 0, processing...
#          Content preview: 'AVAILABLE ON DEMAND
# The Ivanti team has been working hard to move Cherwell Service Management (CSM) ...' (1675 chars)
#
# 📝 Parsing content for PODCAST (Row 12)
#    Expected count: 5
#    Content length: 1675 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 5 raw pieces
#    🧹 After cleaning: 5 valid pieces
#       Piece 1: 436 chars, 71 words
#       Piece 2: 436 chars, 71 words
#       Piece 3: 225 chars, 28 words
#       Piece 4: 225 chars, 28 words
#       Piece 5: 225 chars, 28 words
#    ✂️  Taking first 5 pieces
#          ✅ Added 5 pieces to row data
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'Cherwell
# Ivanti Neurons
# Precision Bridge
# RightAnswers
# Robust IT service management solution that tra...' (18625 chars)
#
# 📝 Parsing content for SHOP (Row 12)
#    Expected count: 10
#    Content length: 18625 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 1770 chars, 227 words
#       Piece 2: 1258 chars, 188 words
#       Piece 3: 475 chars, 59 words
#       Piece 4: 969 chars, 127 words
#       Piece 5: 2114 chars, 297 words
#       Piece 6: 1424 chars, 180 words
#       Piece 7: 1188 chars, 178 words
#       Piece 8: 7075 chars, 1027 words
#       Piece 9: 1157 chars, 154 words
#       Piece 10: 907 chars, 118 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       Row 12 final data: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#
#    🔍 Processing row 13...
#       Metadata: 'ABOUT_US=1,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=5,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 1
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 5
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 1, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 5, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'About the Alliance
# The  paramount mission of the Alliance is to provide our clients with the shared ...' (2649 chars)
#
# 📝 Parsing content for ABOUT_US (Row 13)
#    Expected count: 1
#    Content length: 2649 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 2649 chars, 366 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'CORPORATE STRATEGY
# 1 hr
# 1 h
# Book Now
# Service Description
# Describe your service here. What makes it g...' (3594 chars)
#
# 📝 Parsing content for SERVICES (Row 13)
#    Expected count: 5
#    Content length: 3594 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 5 raw pieces
#    🧹 After cleaning: 5 valid pieces
#       Piece 1: 328 chars, 55 words
#       Piece 2: 332 chars, 55 words
#       Piece 3: 328 chars, 55 words
#       Piece 4: 2057 chars, 259 words
#       Piece 5: 421 chars, 81 words
#    ✂️  Taking first 5 pieces
#          ✅ Added 5 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 13 final data: ['ABOUT_US', 'SERVICES']
#
#    🔍 Processing row 14...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=1,TESTIMONIALS=1,WEBINAR=0,SERVICES=1,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 1
#       Found: TESTIMONIALS = 1
#       Found: WEBINAR = 0
#       Found: SERVICES = 1
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 1, 'TESTIMONIALS': 1, 'WEBINAR': 0, 'SERVICES': 1, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'Bold
# ideas,
# always!
# Studio
# Work
# Contact
# Linkedin
# Facebook
# Vimeo
# Outpost X –
# FASHION CAMPAIGN
# INtro
# F...' (561 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 14)
#    Expected count: 1
#    Content length: 561 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 561 chars, 85 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ✅ Count > 0, processing...
#          Content preview: 'Bold
# ideas,
# always!
# Studio
# Work
# Contact
# Linkedin
# Facebook
# Vimeo
# take a
# look at
# our work
# Weapon Agenc...' (1221 chars)
#
# 📝 Parsing content for TESTIMONIALS (Row 14)
#    Expected count: 1
#    Content length: 1221 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 1221 chars, 160 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Bold
# ideas,
# always!
# Studio
# Work
# Contact
# Linkedin
# Facebook
# Vimeo
# COMMERCIAL INTERIOR DESIGN
# Lorem ips...' (4018 chars)
#
# 📝 Parsing content for SERVICES (Row 14)
#    Expected count: 1
#    Content length: 4018 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 4018 chars, 605 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 14 final data: ['RECENT_BLOG', 'TESTIMONIALS', 'SERVICES']
#
#    🔍 Processing row 15...
#       Metadata: 'ABOUT_US=2,EBOOK=0,COURSES=0,RECENT_BLOG=1,TESTIMONIALS=1,WEBINAR=1,SERVICES=1,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 2
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 1
#       Found: TESTIMONIALS = 1
#       Found: WEBINAR = 1
#       Found: SERVICES = 1
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 2, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 1, 'TESTIMONIALS': 1, 'WEBINAR': 1, 'SERVICES': 1, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'LEADERSHIP TEAM
# SAMIR DAMLE, MS, PhD
# Chief Executive Officer
# Samir has a multidisciplinary backgroun...' (4423 chars)
#
# 📝 Parsing content for ABOUT_US (Row 15)
#    Expected count: 2
#    Content length: 4423 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 3142 chars, 424 words
#       Piece 2: 1249 chars, 185 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'All Posts
# Search
# Check back soon
# Once posts are published, you’ll see them here....' (80 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 15)
#    Expected count: 1
#    Content length: 80 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 80 chars, 14 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ✅ Count > 0, processing...
#          Content preview: 'MEET OUR CLIENTS
# Collaborative Efforts
# AXES
# Career-Long Partner
# VOLVE
# A Fresh Start
# SOVIX
# Starting S...' (130 chars)
#
# 📝 Parsing content for TESTIMONIALS (Row 15)
#    Expected count: 1
#    Content length: 130 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 130 chars, 18 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'To see this working, head to your live site.
# All Posts
# My Posts
# amirzahlan
# Apr 01, 2024
# Edited:
# Apr ...' (1021 chars)
#
# 📝 Parsing content for WEBINAR (Row 15)
#    Expected count: 1
#    Content length: 1021 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 1021 chars, 172 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'OUR SERVICES
# ​
# ​
# Planning and Program Development
# Program Controls
# Procurement Process Management
# De...' (375 chars)
#
# 📝 Parsing content for SERVICES (Row 15)
#    Expected count: 1
#    Content length: 375 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
# ...
#    📤 Response preview: 'Guidelines for Providing Process Conditions for Risk Based Inspection (RBI) Implementation and Revalidation
# by Vibha Zaman, 10/24/2018
# Tags:
# Risk Based Inspection
# Our Senior Corrosion and Mechanical I...'
#          ✅ AI processing complete
#       ✅ Row 325 output: 2245 chars
#
#    📋 Processing row 326 (data index 324)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 326 output: 10 chars
#       📤 Writing batch to range: Sheet2!P322:P326
#
#    📤 Writing batch #65 to sheet range: Sheet2!P322:P326
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #65 for RECENT_BLOG
#
#    📋 Processing row 327 (data index 325)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 327, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 4848 chars
#    Formatting piece 2: 4299 chars
#    Formatting piece 3: 5917 chars
#    Formatting piece 4: 4019 chars
#    Formatting piece 5: 3811 chars
#    Formatting piece 6: 4503 chars
#    Formatting piece 7: 4636 chars
#    Formatting piece 8: 3935 chars
#    Formatting piece 9: 3502 chars
#    Formatting piece 10: 3986 chars
#    ✅ Formatted output: 44256 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 44256 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 3751 characters
#    📤 Response preview: 'Financing Long-Term Care: Your Options Explained
# Michael Wilcox |
# Oct 18, 2021
# Categories
# Health
# It’s not always pleasant to think about who will take care of you when you’re no longer able to take ca...'
#          ✅ AI processing complete
#       ✅ Row 327 output: 3751 chars
#
#    📋 Processing row 328 (data index 326)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 328 output: 10 chars
#
#    📋 Processing row 329 (data index 327)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 329 output: 10 chars
#
#    📋 Processing row 330 (data index 328)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 330 output: 10 chars
#
#    📋 Processing row 331 (data index 329)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 331 output: 10 chars
#       📤 Writing batch to range: Sheet2!P327:P331
#
#    📤 Writing batch #66 to sheet range: Sheet2!P327:P331
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #66 for RECENT_BLOG
#
#    📋 Processing row 332 (data index 330)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 332 output: 10 chars
#
#    📋 Processing row 333 (data index 331)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 333, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'PODCAST', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 663 chars
#    Formatting piece 2: 3260 chars
#    Formatting piece 3: 3861 chars
#    Formatting piece 4: 12018 chars
#    Formatting piece 5: 2952 chars
#    Formatting piece 6: 3821 chars
#    Formatting piece 7: 7568 chars
#    Formatting piece 8: 1017 chars
#    Formatting piece 9: 1414 chars
#    Formatting piece 10: 3537 chars
#    ✅ Formatted output: 40912 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 40912 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 11728 characters
#    📤 Response preview: 'Thinking Through Technology Using Scripture
# By Dr. Josh Mulvihill
#
# I have one tech-free week with my boys every summer, and I love it. For the past two decades, I’ve been driving to Ontario, Canad...'
#          ✅ AI processing complete
#       ✅ Row 333 output: 11728 chars
#
#    📋 Processing row 334 (data index 332)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 334 output: 10 chars
#
#    📋 Processing row 335 (data index 333)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 335 output: 10 chars
#
#    📋 Processing row 336 (data index 334)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 336 output: 10 chars
#       📤 Writing batch to range: Sheet2!P332:P336
#
#    📤 Writing batch #67 to sheet range: Sheet2!P332:P336
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #67 for RECENT_BLOG
#
#    📋 Processing row 337 (data index 335)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 337 output: 10 chars
#
#    📋 Processing row 338 (data index 336)...
#       Found 1 pieces for RECENT_BLOG
#       📋 Single piece -> copying directly (1808 chars)
#       ✅ Row 338 output: 1808 chars
#
#    📋 Processing row 339 (data index 337)...
#       Found 3 pieces for RECENT_BLOG
#       🔄 Multiple pieces (3) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 339, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'RECENT_BLOG', 'SERVICES']
#    Found 3 pieces to format
#    Formatting piece 1: 4433 chars
#    Formatting piece 2: 5770 chars
#    Formatting piece 3: 5091 chars
#    ✅ Formatted output: 15535 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 15535 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 2649 characters
#    📤 Response preview: 'Going Green in Nyssa: Solar Panels as an Environmentally Friendly Choice
# As the world grapples with the increasing effects of climate change, individuals and businesses alike are looking for ways to r...'
#          ✅ AI processing complete
#       ✅ Row 339 output: 2649 chars
#
#    📋 Processing row 340 (data index 338)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 340 output: 10 chars
#
#    📋 Processing row 341 (data index 339)...
#       Found 1 pieces for RECENT_BLOG
#       📋 Single piece -> copying directly (56 chars)
#       ✅ Row 341 output: 56 chars
#       📤 Writing batch to range: Sheet2!P337:P341
#
#    📤 Writing batch #68 to sheet range: Sheet2!P337:P341
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #68 for RECENT_BLOG
#
#    📋 Processing row 342 (data index 340)...
#       Found 6 pieces for RECENT_BLOG
#       🔄 Multiple pieces (6) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 342, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'RECENT_BLOG', 'TESTIMONIALS', 'SERVICES']
#    Found 6 pieces to format
#    Formatting piece 1: 634 chars
#    Formatting piece 2: 295 chars
#    Formatting piece 3: 402 chars
#    Formatting piece 4: 352 chars
#    Formatting piece 5: 308 chars
#    Formatting piece 6: 589 chars
#    ✅ Formatted output: 3041 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 3041 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 591 characters
#    📤 Response preview: 'BLR’s strategic approach to saving you money involves a detailed expense reduction process. Following this process, BLR is able to systematically generate considerable savings in the majority of expen...'
#          ✅ AI processing complete
#       ✅ Row 342 output: 591 chars
#
#    📋 Processing row 343 (data index 341)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 343 output: 10 chars
#
#    📋 Processing row 344 (data index 342)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 344 output: 10 chars
#
#    📋 Processing row 345 (data index 343)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 345, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'PODCAST', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 5794 chars
#    Formatting piece 2: 2576 chars
#    Formatting piece 3: 1614 chars
#    Formatting piece 4: 5153 chars
#    Formatting piece 5: 5261 chars
#    Formatting piece 6: 6400 chars
#    Formatting piece 7: 3725 chars
#    Formatting piece 8: 5390 chars
#    Formatting piece 9: 3037 chars
#    Formatting piece 10: 4701 chars
#    ✅ Formatted output: 44453 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 44453 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 5979 characters
#    📤 Response preview: 'Market Milestones: Bitcoin Bull Market Support
# Yates Craig
# Published on: 04/09/2025
# September has historically been a weak month for Bitcoin and this one is setting up no differently. The curren...'
#          ✅ AI processing complete
#       ✅ Row 345 output: 5979 chars
#
#    📋 Processing row 346 (data index 344)...
#       Found 5 pieces for RECENT_BLOG
#       🔄 Multiple pieces (5) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 346, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 5 pieces to format
#    Formatting piece 1: 18206 chars
#    Formatting piece 2: 17340 chars
#    Formatting piece 3: 4499 chars
#    Formatting piece 4: 7268 chars
#    Formatting piece 5: 654 chars
#    ✅ Formatted output: 48374 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 48374 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 4499 characters
#    📤 Response preview: 'Client Spotlight: Hot Flash Wines
# January 6, 2014 / by
# Raquel Royers
# Tweet
# We would like to congratulate one of our clients on her start-up business
# Hot Flash Wines
# . After months of hard work Mollie ...'
#          ✅ AI processing complete
#       ✅ Row 346 output: 4499 chars
#       📤 Writing batch to range: Sheet2!P342:P346
#
#    📤 Writing batch #69 to sheet range: Sheet2!P342:P346
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #69 for RECENT_BLOG
#
#    📋 Processing row 347 (data index 345)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 347 output: 10 chars
#
#    📋 Processing row 348 (data index 346)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 348 output: 10 chars
#
#    📋 Processing row 349 (data index 347)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 349, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 4656 chars
#    Formatting piece 2: 4213 chars
#    Formatting piece 3: 7407 chars
#    Formatting piece 4: 3500 chars
#    Formatting piece 5: 2941 chars
#    Formatting piece 6: 3427 chars
#    Formatting piece 7: 3302 chars
#    Formatting piece 8: 4357 chars
#    Formatting piece 9: 3075 chars
#    Formatting piece 10: 2819 chars
#    ✅ Formatted output: 40500 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 40500 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 3442 characters
#    📤 Response preview: 'eCampus login
# Toll Free 1-877-257-9777
# Home
# State Training
# Stormwater Management
# Clean Water Act
# Oil and Gas
# 4 Divisions of Stormwater
# Watersheds/ TMDLs/WQS
# Stormwater Plans
# Erosion and Sediment
# Suppo...'
#          ✅ AI processing complete
#       ✅ Row 349 output: 3442 chars
#
#    📋 Processing row 350 (data index 348)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 350 output: 10 chars
#
#    📋 Processing row 351 (data index 349)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 351 output: 10 chars
#       📤 Writing batch to range: Sheet2!P347:P351
#
#    📤 Writing batch #70 to sheet range: Sheet2!P347:P351
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #70 for RECENT_BLOG
#
#    📋 Processing row 352 (data index 350)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 352, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 1133 chars
#    Formatting piece 2: 1183 chars
#    Formatting piece 3: 1112 chars
#    Formatting piece 4: 1421 chars
#    Formatting piece 5: 1282 chars
#    Formatting piece 6: 4275 chars
#    Formatting piece 7: 4395 chars
#    Formatting piece 8: 4135 chars
#    Formatting piece 9: 4313 chars
#    Formatting piece 10: 2376 chars
#    ✅ Formatted output: 26420 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 26420 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 668 characters
#    📤 Response preview: 'Proving Apprenticeship Program Impact in the Manufacturing Industry
# Each year, nearly 200 students participate in work-based learning programs designed by GPSEd. These students are immersed in hands-o...'
#          ✅ AI processing complete
#       ✅ Row 352 output: 668 chars
#
#    📋 Processing row 353 (data index 351)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 353 output: 10 chars
#    📤 Writing final batch to range: Sheet2!P352:P353
#
#    📤 Writing batch #final to sheet range: Sheet2!P352:P353
#    📊 Writing 2 values
#    ✅ Successfully wrote batch #final for RECENT_BLOG
# ✅ Completed blog category: RECENT_BLOG
#
# 🎉 Pipeline completed successfully!
