# %%
from googleapiclient.discovery import build
from google.oauth2 import service_account
from openai import OpenAI
import time

# Configuration
CREDENTIALS_FILE = "data/url-to-email-445616-cebe4868914f.json"
SPREADSHEET_ID = "1FFZ0c_SgpAcYgLU2gtVx4IFCFhOcQqf8DRdsarhCd_I"
SHEET_NAME = "Sheet2"
OPENAI_API_KEY = ""

# Column mapping for your data
column_indices = {
	"FIRST_NAME": 0,  	# Column A
	"COMPANY_NAME": 3,  # Column D
	"ABOUT_US": 12,  		# M
	"EBOOK": 13,     		# N
	"COURSES": 14,   		# O
	"RECENT_BLOG": 15, 	# P
	"TESTIMONIALS": 16, # Q
	"WEBINAR": 17,   		# R
	"SERVICES": 18,  		# S
	"PODCAST": 19,   		# T
	"SHOP": 20       		# U 
}

# Output column for the generated email
OUTPUT_COLUMN = "W"

# %%
BASE_PROMPT = """
Objective: Generate initial cold emails openings for outreach, following the specific template provided below. Only modify the sections within square brackets for personalisation; all other content should remain fixed.
 
Instructions:
  - Personalization Fields:
    - Replace [FIRST NAME] with the name of the person given in the prompt.
    - Replace [PERSONALISATION] with a short, specific comment as per the instruction given in the square bracket of [PERSONALISATION - instruction here].
    - The short specific comment as mentioned above should provide some sort of insight and it should go along and tie in to the next line in the email template so that the overall email can make sense. 
    - While personalizing: Write the personalization in 3rd Grade level. The sentence should not be too long and complex. Use shorter sentences and simpler words.
  - Fixed Content:
    - Do not change any other text in the template. All non-bracketed content should remain exactly as written, preserving the wording, tone, and format. Be very very strict on this, I don't want anything else apart from the bracketed  content to change. 
  - Tone and Language:
    - Keep the tone friendly and professional.
  - Don't send anything else except for the Email opening in the output
  - Judge if the given data point is useful for the same, if not send "NONSENSICAL DATA POINT" in the output – VERY VERY IMPORTANT

Here's the template I'm using:

Saw you are helping [their ICP, be very specific with it based on the data points] with [very specific problem they're helping their ICP with], {{First Name}} 


[Compliment the Insight on how we think it's helping their ICP overcome that problem. Share what's the end benefits on how it's helping their ICP.]

===================

Examples based on this Template:

EXAMPLE - 1 : 

Saw you are helping companies with unconscious bias training, Marguerite.

I think it's great how you help people see their own biases. That makes workshops better for everyone

EXAMPLE - 2 :

Saw you are helping organizations improve their processes and build high-performing teams, Kevin.

I think it's wonderful how you help teams work together better and reach their goals. That is super important! 

EXAMPLE - 3 :

Saw you are helping communities in Uganda with access to healthcare, education, justice, and environmental sustainability, Steven.

I think it's wonderful how you empower children and transform lives. That is super important! 

===================

•⁠  ⁠Do the personalization using the pool of knowledge from the data points I'm giving you
•⁠  ⁠Looking at the data pool you'd be able to tell what's the profile of the prospect we're trying to reach out to and what kind of customers do they serve and what pain points do our prospects help their customers overcome.

•⁠  ⁠An Example of an Email that is strictly following the rules:

"Saw you are helping marketers adapt to the changes in digital privacy and data collection, Rydal.

It’s cool that you are helping them get ready for the cookieless future. That is super important!"

I really like the fact that the above email is sticking to the template and using the personalization on the first line alone as mentioned in the instructions.
"""

# %%
# BASE_PROMPT = """
# Objective: Generate initial cold emails for outreach, following the specific template provided below. Only modify the sections within square brackets for personalisation; all other content should remain fixed.
 
#          Instructions:
#          - Personalization Fields:
#              - Replace [FIRST NAME] with the name of the person given in the prompt.
#              - Replace [PERSONALISATION] with a short, specific comment as per the instruction given in the square bracket of [PERSONALISATION - instruction here].
#              - The short specific comment as mentioned above should provide some sort of insight and it should go along and tie in to the next line in the email template so that the overall email can make sense. 
#              - While personalizing: Write the personalization in 3rd Grade level. The sentence should not be too long and complex. Use shorter sentences and simpler words.
#          - Fixed Content:
#              - Do not change any other text in the template. All non-bracketed content should remain exactly as written, preserving the wording, tone, and format. Be very very strict on this, I don't want anything else apart from the bracketed  content to change. 
#          - Tone and Language:
#              - Keep the tone friendly and professional.
#              - Ensure the language is simple, conversational, and concise to stay within the ~150-word limit.
#          - Don't send anything else except for the Email in the output
#          - Judge if the given data point is useful for the same, if not send "NONSENSICAL DATA POINT" in the output – VERY VERY IMPORTANT

# Here's the template I'm using:

# Saw you are helping [their ICP, be very specific with it based on the data points] with [very specific problem they’re helping their ICP with], {{First Name}} 

# But what if that genius got seen by 10X more prospects?

# We help experts like Katie Melissa boost clients by 287% in 45 days. 

# How? 

# By featuring your insights across our 200M+ follower network—zero effort from you.

# This turns strangers into buyers almost instantly.

# Wanna see how we’d spotlight your method?

# ===================

# Example based on this Template:

# Saw you are helping construction companies with labor shortages, James.

# But what if that genius got seen by 10X more prospects?

# We help experts like Katie Melissa boost clients by 287% in 45 days. 

# How? 

# By featuring your insights across our 200M+ follower network—zero effort from you.

# This turns strangers into buyers almost instantly.

# Wanna see how we’d spotlight your method?

# ===================

# •⁠  ⁠Apart from the first line in the template the other lines will remain the same.
# •⁠  ⁠Do the personalization using the pool of knowledge from the data points I'm giving you
# •⁠  ⁠Looking at the data pool you'd be able to tell what's the profile of the prospect we're trying to reach out to and what kind of customers do they serve and what pain points do our prospects help their customers overcome.

# •⁠  ⁠An Example of an Email that is strictly following the rules:
# "Saw you are helping small businesses with their accounting and tax needs, Gary.

# But what if that genius got seen by 10X more prospects?

# We help experts like Katie Melissa boost clients by 287% in 45 days. 

# How? 

# By featuring your insights across our 200M+ follower network—zero effort from you.

# This turns strangers into buyers almost instantly.

# Wanna see how we’d spotlight your method?"

# I really like the fact that the above email is sticking to the template and using the personalization on the first line alone as mentioned in the instructions.

# •⁠  ⁠Example of Email that doesn't follow the rules:
# "Saw you are helping non-profit organizations with financial management, Harriet.

# I saw your team helps people manage money better. That is really important for those groups!

# But what if that genius got seen by 10X more prospects?

# We help experts like Katie Melissa boost clients by 287% in 45 days. 

# How? 

# By featuring your insights across our 200M+ follower network—zero effort from you.

# This turns strangers into buyers almost instantly.

# Wanna see how we’d spotlight your method?"

# This is not a good example of how the template is supposed to be followed. Since it added a line on it's own and I didn't ask for it. To be more specific the 2nd line i.e, 'I saw your team helps people manage money better. That is really important for those groups!' is extra and uncalled for. DO NOT ADD LINES LIKE THESE ON YOUR OWN AND STRICTLY FOLLOW THE INSTRUCTIONS AND PROMPTS GIVEN.
# """

# %%
def authenticate_google_sheets():
    """Authenticate and return Google Sheets service"""
    try:
        creds = service_account.Credentials.from_service_account_file(
            CREDENTIALS_FILE, 
            scopes=['https://www.googleapis.com/auth/spreadsheets']
        )
        service = build('sheets', 'v4', credentials=creds)
        return service
    except Exception as e:
        print(f"Error authenticating Google Sheets: {e}")
        return None

def initialize_openai():
    """Initialize OpenAI client"""
    try:
        client = OpenAI(api_key=OPENAI_API_KEY)
        return client
    except Exception as e:
        print(f"Error initializing OpenAI: {e}")
        return None

def collect_all_usable_datapoints(row):
    """Collect all usable datapoints from a row"""
    datapoints = {}
    
    for category, col_index in column_indices.items():
        # Skip non-datapoint columns like name and company
        if category in ["FIRST_NAME", "COMPANY_NAME"]:
            continue
            
        if col_index < len(row):
            content = str(row[col_index]).strip()
            
            # Check if content is usable (not empty, not "no content", etc.)
            if (content and 
                content.lower() != "no content" and 
                content.lower() != "no meaningful content" and
                content.strip() != ""):
                datapoints[category] = content
    
    return datapoints

def generate_email(first_name, company_name, datapoints, client):
    """Generate email using all available datapoints"""
    try:
        # Prepare datapoints for the prompt
        datapoints_text = ""
        for category, content in datapoints.items():
            datapoints_text += f"{category}: {content}\n"
        
        prompt = f"""
        {BASE_PROMPT}
        
        Person's first name: {first_name}
        Company name: {company_name}
        
        Available datapoints to personalize with:
        {datapoints_text}
        
        Generate a personalized email using ALL the datapoints provided.
        """
        
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=500,
            temperature=0.7
        )
        
        return response.choices[0].message.content.strip()
    
    except Exception as e:
        print(f"Error generating email: {e}")
        return f"Error generating email: {str(e)}"

def process_row(row, row_index, client):
    """Process a single row and generate an email"""
    try:
        # Extract basic information
        first_name = str(row[column_indices["FIRST_NAME"]]).strip() if len(row) > column_indices["FIRST_NAME"] else "Friend"
        company_name = str(row[column_indices["COMPANY_NAME"]]).strip() if len(row) > column_indices["COMPANY_NAME"] else "Your Company"
        
        print(f"Processing row {row_index + 2}: {first_name} from {company_name}")  # +2 to account for 0-indexing and header
        
        # Collect all usable datapoints
        datapoints = collect_all_usable_datapoints(row)
        print(f"  Found {len(datapoints)} usable datapoints")
        
        # Generate email with all datapoints
        email_content = generate_email(
            first_name,
            company_name,
            datapoints,
            client
        )
        
        return email_content
    
    except Exception as e:
        print(f"Error processing row {row_index + 2}: {e}")
        return f"Error: {str(e)}"

def update_sheet_with_results(service, results):
    """Update the Google Sheet with generated emails"""
    try:
        # Prepare batch update data
        data = []
        
        for row_index, email_content in results:
            if email_content is None:
                continue
                
            actual_row = row_index + 2  # Assuming header is row 1, data starts from row 2
            cell_range = f"{SHEET_NAME}!{OUTPUT_COLUMN}{actual_row}"
            
            data.append({
                'range': cell_range,
                'values': [[email_content]]
            })
        
        if data:
            body = {
                'valueInputOption': 'RAW',
                'data': data
            }
            
            result = service.spreadsheets().values().batchUpdate(
                spreadsheetId=SPREADSHEET_ID,
                body=body
            ).execute()
            
            print(f"Updated {len(data)} cells in the spreadsheet")
            return True
        else:
            print("No data to update")
            return False
    
    except Exception as e:
        print(f"Error updating sheet: {e}")
        return False

# %%
def main(start_row=1):
    """Main function to run the email generation process with batch processing
    Args:
        start_row (int): Row number to start processing from (1-based, excluding header)
    """
    print(f"Starting email generation process from row {start_row}...")
    
    # Initialize services
    sheets_service = authenticate_google_sheets()
    if not sheets_service:
        print("Failed to authenticate Google Sheets")
        return
        
    openai_client = initialize_openai()
    if not openai_client:
        print("Failed to initialize OpenAI client")
        return
        
    try:
        # Read data from Google Sheets
        range_name = f"{SHEET_NAME}!A:Z"  # Adjust range as needed to include all your columns
        result = sheets_service.spreadsheets().values().get(
            spreadsheetId=SPREADSHEET_ID,
            range=range_name
        ).execute()
        
        values = result.get('values', [])
        if not values:
            print('No data found in the sheet.')
            return
            
        # Skip header row and validate start_row
        data_rows = values[1:]  # Skip header
        total_rows = len(data_rows)
        print(f"Found {total_rows} data rows in the sheet")
        
        # Validate start_row
        if start_row < 1:
            print("Error: start_row must be >= 1")
            return
        elif start_row > total_rows:
            print(f"Error: start_row ({start_row}) is greater than total rows ({total_rows})")
            return
            
        # Adjust for 0-based indexing (start_row is 1-based)
        start_index = start_row - 1
        remaining_rows = data_rows[start_index:]
        remaining_count = len(remaining_rows)
        print(f"Starting from row {start_row}, processing {remaining_count} remaining rows")
        
        batch_size = 10
        results = []
        
        # Process rows in batches
        for batch_start in range(0, remaining_count, batch_size):
            batch_end = min(batch_start + batch_size, remaining_count)
            batch_rows = remaining_rows[batch_start:batch_end]
            
            print(f"\nProcessing batch: rows {start_row + batch_start} to {start_row + batch_end - 1}")
            
            # Process each row in the current batch
            batch_results = []
            for i, row in enumerate(batch_rows):
                actual_row_index = start_index + batch_start + i  # Global row index
                email_content = process_row(row, actual_row_index, openai_client)
                batch_results.append((actual_row_index, email_content))
                
                # Add delay to avoid rate limiting
                time.sleep(1)
            
            # Add to overall results
            results.extend(batch_results)
            
            # Update the sheet with this batch's results
            if update_sheet_with_results(sheets_service, batch_results):
                print(f"✅ Batch completed successfully!")
            else:
                print(f"❌ Failed to update batch")
                print("Stopping process to prevent data loss...")
                break
        
        print(f"\n🎉 Email generation completed! Successfully processed {len(results)} rows.")
    
    except Exception as e:
        print(f"Error in main process: {e}")

# %%
await main(start_row=1)
# Out:
# Starting email generation process from row 1...
# Found 353 data rows in the sheet
# Starting from row 1, processing 353 remaining rows
#
# Processing batch: rows 1 to 10
# Processing row 2: Chad from BLACK DIAMOND CONSULTANTS
#   Found 1 usable datapoints
# Processing row 3: Al from 1903 Solutions
#   Found 2 usable datapoints
# Processing row 4: Gloria from LiveWell Behavioral Health
#   Found 8 usable datapoints
# Processing row 5: Carmen from Evolution Development Group
#   Found 1 usable datapoints
# Processing row 6: Martha from Outsourced Accounting Services
#   Found 0 usable datapoints
# Processing row 7: Lindsay from DevelopAbilene
#   Found 0 usable datapoints
# Processing row 8: Daniel from Icetro America
#   Found 7 usable datapoints
# Processing row 9: Greg from Electronic Support
#   Found 9 usable datapoints
# Processing row 10: John from ProAct
#   Found 3 usable datapoints
# Processing row 11: Win from Baca Stein White & Associates
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 11 to 20
# Processing row 12: Steven from Avante Solutions
#   Found 8 usable datapoints
# Processing row 13: James from The Education Alliance
#   Found 2 usable datapoints
# Processing row 14: Ash from Weapon Agency
#   Found 3 usable datapoints
# Processing row 15: Nikhil from Enterris Associates
#   Found 5 usable datapoints
# Processing row 16: Frank from ACS Global Ventures
#   Found 7 usable datapoints
# Processing row 17: Jenifer from Stardust Celebrations
#   Found 0 usable datapoints
# Processing row 18: Charlene from Honeycutt
#   Found 0 usable datapoints
# Processing row 19: David from Electronic Support
#   Found 9 usable datapoints
# Processing row 20: Kelley from The Ford Institute
#   Found 0 usable datapoints
# Processing row 21: John from AT Tax Advisory
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 21 to 30
# Processing row 22: Elizabeth from The International Social Impact Institute®
#   Found 0 usable datapoints
# Processing row 23: Nazar from Dispatch & Services
#   Found 1 usable datapoints
# Processing row 24: Irene from Innerscapes
#   Found 3 usable datapoints
# Processing row 25: David from Quality Business Solutions
#   Found 8 usable datapoints
# Processing row 26: Ellen from Fruchtman Marketing
#   Found 9 usable datapoints
# Processing row 27: Suzie from Red Technologies MN TX
#   Found 0 usable datapoints
# Processing row 28: Rachael from 360 Community Management
#   Found 6 usable datapoints
# Processing row 29: Abe from Plaza Auto Leasing & Sales
#   Found 4 usable datapoints
# Processing row 30: Sirisha from IRIS INFOTECH
#   Found 2 usable datapoints
# Processing row 31: Samuel from The Dickman Company
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 31 to 40
# Processing row 32: Christina from Embracing Our Differences
#   Found 3 usable datapoints
# Processing row 33: Steve from BCC Advisers
#   Found 0 usable datapoints
# Processing row 34: Alex from The Montag Group
#   Found 0 usable datapoints
# Processing row 35: Shoshana from Alloy Fundraising
#   Found 5 usable datapoints
# Processing row 36: Rick from CSz Portland
#   Found 0 usable datapoints
# Processing row 37: Daniel from Wellness Worx
#   Found 3 usable datapoints
# Processing row 38: Joyce from STORM
#   Found 3 usable datapoints
# Processing row 39: Meggan from MindWire
#   Found 8 usable datapoints
# Processing row 40: Kimberle from All Wired Up
#   Found 2 usable datapoints
# Processing row 41: Jeffrey from Electrical Design Consultants
#   Found 3 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 41 to 50
# Processing row 42: Jack from CollegeAPP
#   Found 0 usable datapoints
# Processing row 43: Ted from Resource Management Services
#   Found 5 usable datapoints
# Processing row 44: Kudzu from Kudzu Brands
#   Found 0 usable datapoints
# Processing row 45: Trey from E Cube
#   Found 0 usable datapoints
# Processing row 46: Paul from Florida REPs
#   Found 3 usable datapoints
# Processing row 47: James from FOSTER CONSULTANTS
#   Found 0 usable datapoints
# Processing row 48: Bob from The Aurelia Foundation
#   Found 7 usable datapoints
# Processing row 49: Don from CICG
#   Found 5 usable datapoints
# Processing row 50: Aki from Ideal Staffing
#   Found 2 usable datapoints
# Processing row 51: Will from MiliMatch
#   Found 3 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 51 to 60
# Processing row 52: Alexander from The Board Game Co
#   Found 3 usable datapoints
# Processing row 53: Max from Mindful Living LCSW
#   Found 4 usable datapoints
# Processing row 54: John from Complete AV
#   Found 3 usable datapoints
# Processing row 55: Dave from Alliance Credit Union
#   Found 0 usable datapoints
# Processing row 56: Stacie from Paulinasalen.com
#   Found 0 usable datapoints
# Processing row 57: Katia from Blink IT Solutions
#   Found 0 usable datapoints
# Processing row 58: Apoorva from Lupa
#   Found 0 usable datapoints
# Processing row 59: Rumen from Magnolia Grove Insurance Services
#   Found 0 usable datapoints
# Processing row 60: Mike from ACS Global Ventures
#   Found 7 usable datapoints
# Processing row 61: Heidi from Scudder Law Firm
#   Found 2 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 61 to 70
# Processing row 62: Duane from RISE INDY
#   Found 7 usable datapoints
# Processing row 63: Matt from Maine Teen Camp
#   Found 5 usable datapoints
# Processing row 64: Miguel from Transnet Communications
#   Found 0 usable datapoints
# Processing row 65: Anthony from Veratics
#   Found 0 usable datapoints
# Processing row 66: Kyle from Teamworthy Ventures
#   Found 2 usable datapoints
# Processing row 67: Brian from SF Tots
#   Found 0 usable datapoints
# Processing row 68: Allyson from Echelon Performance
#   Found 9 usable datapoints
# Processing row 69: Krysten from Every Mother's Advocate
#   Found 8 usable datapoints
# Processing row 70: Taras from Tbest Services
#   Found 0 usable datapoints
# Processing row 71: Kyla from PMI
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 71 to 80
# Processing row 72: Karly from Independent Consultant
#   Found 0 usable datapoints
# Processing row 73: Ed from KEYGroup
#   Found 0 usable datapoints
# Processing row 74: Dalila from Optimir Consulting
#   Found 3 usable datapoints
# Processing row 75: Erika from MFHA
#   Found 7 usable datapoints
# Processing row 76: Truc from NexLearn
#   Found 0 usable datapoints
# Processing row 77: Tree from Providence Consulting Company
#   Found 8 usable datapoints
# Processing row 78: Tom from Argo Navis
#   Found 5 usable datapoints
# Processing row 79: Maggie from Dodson Payment Solutions
#   Found 0 usable datapoints
# Processing row 80: Daniel from Red Wall
#   Found 1 usable datapoints
# Processing row 81: Rachel from Family Wealth Alliance
#   Found 8 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 81 to 90
# Processing row 82: Arshad from NetHyve
#   Found 0 usable datapoints
# Processing row 83: Robin from MyLifeWerks Insurance Services
#   Found 6 usable datapoints
# Processing row 84: Phil from Pivoten
#   Found 5 usable datapoints
# Processing row 85: Barbara from Chaos Visual Productions
#   Found 6 usable datapoints
# Processing row 86: Ty from 6blu
#   Found 0 usable datapoints
# Processing row 87: Alison from Animalistic Industries
#   Found 0 usable datapoints
# Processing row 88: Harry from Stonecourt Capital
#   Found 0 usable datapoints
# Processing row 89: Jeremme from Group West Construction
#   Found 2 usable datapoints
# Processing row 90: Melissa from Align Social Impact
#   Found 0 usable datapoints
# Processing row 91: Sonya from Just-In Time Moving & Storage
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 91 to 100
# Processing row 92: Madison from Tier One Solutions
#   Found 4 usable datapoints
# Processing row 93: Abbie from Panaro Group
#   Found 6 usable datapoints
# Processing row 94: Michael from Westwood & Wilshire
#   Found 0 usable datapoints
# Processing row 95: Consuelo from Absolute Investment Realty
#   Found 1 usable datapoints
# Processing row 96: Marvin from Yatooma Oil
#   Found 0 usable datapoints
# Processing row 97: Christopher from 2A Marketing
#   Found 7 usable datapoints
# Processing row 98: Lauren from SalterMitchell PR
#   Found 5 usable datapoints
# Processing row 99: Michael from Thoughtium
#   Found 5 usable datapoints
# Processing row 100: Amy from Easter Associates
#   Found 5 usable datapoints
# Processing row 101: Preston from kstate CREDIT UNION
#   Found 7 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 101 to 110
# Processing row 102: Michael from Digital Bridge
#   Found 0 usable datapoints
# Processing row 103: Jessica from H.H. Morgan Enterprises
#   Found 4 usable datapoints
# Processing row 104: Jim from Movement.org
#   Found 5 usable datapoints
# Processing row 105: Linda from Solomon Schechter Day School of Greater Monmouth County
#   Found 6 usable datapoints
# Processing row 106: Joseph from 3 Tree Tech
#   Found 7 usable datapoints
# Processing row 107: Frederique from The Altman Building
#   Found 5 usable datapoints
# Processing row 108: Will from Capital BPM
#   Found 7 usable datapoints
# Processing row 109: Melissa from Qual IT Resources
#   Found 4 usable datapoints
# Processing row 110: Michael from AmeriCrew
#   Found 4 usable datapoints
# Processing row 111: Kimberly from Isuzu Motors America
#   Found 6 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 111 to 120
# Processing row 112: Dan from Top Source International
#   Found 3 usable datapoints
# Processing row 113: Janet from Greater Providence Chamber of Commerce
#   Found 3 usable datapoints
# Processing row 114: Aubrey from Sonburst Communication
#   Found 1 usable datapoints
# Processing row 115: Cassandra from Reliance Property Management
#   Found 0 usable datapoints
# Processing row 116: Kathy from Human Potential Center
#   Found 7 usable datapoints
# Processing row 117: Scott from P2P Global
#   Found 0 usable datapoints
# Processing row 118: Katlin from PUSH
#   Found 0 usable datapoints
# Processing row 119: Christian from Client Ascension
#   Found 3 usable datapoints
# Processing row 120: John from YellowTelescope
#   Found 0 usable datapoints
# Processing row 121: Sarah from BRYANT GROUP
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 121 to 130
# Processing row 122: Troy from Finest Known
#   Found 9 usable datapoints
# Processing row 123: Sean from Praevius Group
#   Found 5 usable datapoints
# Processing row 124: Austin from SLC Bookkeeping
#   Found 0 usable datapoints
# Processing row 125: Edward from Kodet Architectural Group
#   Found 0 usable datapoints
# Processing row 126: Brock from UbiStor
#   Found 6 usable datapoints
# Processing row 127: Tracy from UpRys
#   Found 4 usable datapoints
# Processing row 128: Jack from Reddy
#   Found 5 usable datapoints
# Processing row 129: Lata from Amplify
#   Found 2 usable datapoints
# Processing row 130: Kami from Arkansas Bankers Association
#   Found 8 usable datapoints
# Processing row 131: Michael from NYC Office Suites
#   Found 8 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 131 to 140
# Processing row 132: Rama from SphereNY
#   Found 2 usable datapoints
# Processing row 133: Melissa from Mehr Consultancy
#   Found 4 usable datapoints
# Processing row 134: Seleni from Tesani Companies
#   Found 7 usable datapoints
# Processing row 135: Stacy from CatalyzeX
#   Found 5 usable datapoints
# Processing row 136: Raymond from ALT TAB Consulting USA
#   Found 4 usable datapoints
# Processing row 137: Kristen from RJ Health
#   Found 0 usable datapoints
# Processing row 138: Michael from Field2Base
#   Found 3 usable datapoints
# Processing row 139: Kevin from Forefront Technology Solutions
#   Found 2 usable datapoints
# Processing row 140: Nicole from Congressional Management Foundation
#   Found 0 usable datapoints
# Processing row 141: Michelle from Operations & Quality Systems Improvement Experts
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 141 to 150
# Processing row 142: Sue from Creative Data Resources
#   Found 0 usable datapoints
# Processing row 143: Lauren from eqHR Solutions
#   Found 7 usable datapoints
# Processing row 144: Natasha from Academy for Continued Healthcare Learning
#   Found 3 usable datapoints
# Processing row 145: Hansa from The Center for Understanding in Conflict
#   Found 0 usable datapoints
# Processing row 146: Karen from Abbey Consulting
#   Found 2 usable datapoints
# Processing row 147: Rachel from Resource Management
#   Found 6 usable datapoints
# Processing row 148: Elizabeth from Institute for International Medicine
#   Found 0 usable datapoints
# Processing row 149: Ginger from MGM Association Management
#   Found 7 usable datapoints
# Processing row 150: Suzanne from Moment Magazine
#   Found 8 usable datapoints
# Processing row 151: Venkat from Cognial
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 151 to 160
# Processing row 152: Taneshia from Skillionaire Games by skillsgapp
#   Found 6 usable datapoints
# Processing row 153: Matthias from FluidEdge Life Sciences
#   Found 0 usable datapoints
# Processing row 154: Larry from ACXSS
#   Found 3 usable datapoints
# Processing row 155: Camille from Rescue Training International
#   Found 5 usable datapoints
# Processing row 156: Ryan from Bonaventure Pro
#   Found 0 usable datapoints
# Processing row 157: Drew from High Ticket Teams
#   Found 1 usable datapoints
# Processing row 158: Alisa from U.S. Black Chambers
#   Found 0 usable datapoints
# Processing row 159: Rachel from Pharos Resources
#   Found 4 usable datapoints
# Processing row 160: Prycilla from Realty Advisory Group
#   Found 0 usable datapoints
# Processing row 161: Sarah from Trinity Christian Academy
#   Found 8 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 161 to 170
# Processing row 162: Hunter from Elite Resources Premier Staffing
#   Found 3 usable datapoints
# Processing row 163: Ron from High Ticket Teams
#   Found 1 usable datapoints
# Processing row 164: Samuel from SportsNutriPros
#   Found 5 usable datapoints
# Processing row 165: Ivey from Priority Communications-Indiana
#   Found 6 usable datapoints
# Processing row 166: Kevin from EZMarketing Agency
#   Found 9 usable datapoints
# Processing row 167: Susan from Beit Ruth for Young Women and Girls At Risk
#   Found 0 usable datapoints
# Processing row 168: Yvette from Boys & Girls Clubs of Jackson County
#   Found 2 usable datapoints
# Processing row 169: Amy from Caption Consulting
#   Found 0 usable datapoints
# Processing row 170: Amy from Raving Consulting Company
#   Found 0 usable datapoints
# Processing row 171: Chad from Feathers To Fur
#   Found 3 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 171 to 180
# Processing row 172: Patrick from College Solutions
#   Found 0 usable datapoints
# Processing row 173: Susan from CBY Professional Services
#   Found 4 usable datapoints
# Processing row 174: Christine from S. Lawrence
#   Found 0 usable datapoints
# Processing row 175: Mike from Greater Providence Chamber of Commerce
#   Found 5 usable datapoints
# Processing row 176: Cate from Seattle Hospitality Group
#   Found 0 usable datapoints
# Processing row 177: Stephen from Resurgence Counseling Center
#   Found 0 usable datapoints
# Processing row 178: Clarke from Datafrond
#   Found 9 usable datapoints
# Processing row 179: William from Inclusity
#   Found 7 usable datapoints
# Processing row 180: Julie from NXT GEN
#   Found 3 usable datapoints
# Processing row 181: Trystan from PayrAdvisors
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 181 to 190
# Processing row 182: George from Dakota Credit Union Association
#   Found 9 usable datapoints
# Processing row 183: Lori from AIM HR Solutions
#   Found 0 usable datapoints
# Processing row 184: Brady from Pathfinder
#   Found 1 usable datapoints
# Processing row 185: Jessica from TechGROWTH Ohio
#   Found 0 usable datapoints
# Processing row 186: Allan from EcommerceRecruiter.com
#   Found 0 usable datapoints
# Processing row 187: Steve from OPSdesign Consulting
#   Found 8 usable datapoints
# Processing row 188: Kevin from Urban League of Kansas
#   Found 3 usable datapoints
# Processing row 189: Leahcim from Above or Beyond
#   Found 6 usable datapoints
# Processing row 190: Tony from The Seismic Group
#   Found 0 usable datapoints
# Processing row 191: Paul from Ascent Dealer Services
#   Found 5 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 191 to 200
# Processing row 192: Chris from AIC Global Staffing
#   Found 1 usable datapoints
# Processing row 193: Daniel from LearnPlatform by Instructure
#   Found 1 usable datapoints
# Processing row 194: Mark from WorkCompCollege.com
#   Found 8 usable datapoints
# Processing row 195: Melanie from JCG Tax Advisors
#   Found 0 usable datapoints
# Processing row 196: Jeffrey from Bâton Global
#   Found 8 usable datapoints
# Processing row 197: Estevao from Kaer Construction
#   Found 0 usable datapoints
# Processing row 198: Tiffany from Arts Conservatory For Teens
#   Found 0 usable datapoints
# Processing row 199: Sean from Feet First California
#   Found 3 usable datapoints
# Processing row 200: Prasenjit from FashioNXT
#   Found 8 usable datapoints
# Processing row 201: Scott from M37 Ventures
#   Found 2 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 201 to 210
# Processing row 202: Charles from CPC Consultants
#   Found 0 usable datapoints
# Processing row 203: Jo-Elle from Revenue Rocket Consulting Group
#   Found 0 usable datapoints
# Processing row 204: Michael from Elite Tech Install
#   Found 5 usable datapoints
# Processing row 205: Ellen from GrantStation.com
#   Found 7 usable datapoints
# Processing row 206: Robert from Applied Ballistics
#   Found 5 usable datapoints
# Processing row 207: Julie from Congenital Hyperinsulinism International
#   Found 6 usable datapoints
# Processing row 208: Adam from Higher Level Education
#   Found 0 usable datapoints
# Processing row 209: Satish from EdWise Group
#   Found 5 usable datapoints
# Processing row 210: Suzanna from Harmony Plus
#   Found 7 usable datapoints
# Processing row 211: Christopher from Medina Tech
#   Found 1 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 211 to 220
# Processing row 212: Michael from ILC Studios
#   Found 0 usable datapoints
# Processing row 213: David from Eduvantis
#   Found 1 usable datapoints
# Processing row 214: Robbie from Travel Destinations Inc. & Its Family of Agencies
#   Found 0 usable datapoints
# Processing row 215: Shannon from Equus Flight Academy
#   Found 2 usable datapoints
# Processing row 216: Luis from Salcedo Group
#   Found 1 usable datapoints
# Processing row 217: Candice from Terra Veta
#   Found 0 usable datapoints
# Processing row 218: Kenn from Strategic Resources Consulting
#   Found 6 usable datapoints
# Processing row 219: Paul from NXT GEN
#   Found 3 usable datapoints
# Processing row 220: Brian from Gould Group
#   Found 4 usable datapoints
# Processing row 221: Chuck from Violand Management Associates
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 221 to 230
# Processing row 222: Frank from International Guide Academy
#   Found 4 usable datapoints
# Processing row 223: Philipp from World Steel Dynamics
#   Found 3 usable datapoints
# Processing row 224: Jerry from CCR Growth
#   Found 7 usable datapoints
# Processing row 225: Ana from engenium
#   Found 0 usable datapoints
# Processing row 226: Zachariah from High Street Consulting
#   Found 5 usable datapoints
# Processing row 227: Jeff from Apex3
#   Found 2 usable datapoints
# Processing row 228: Brian from SkyTide Group
#   Found 0 usable datapoints
# Processing row 229: Josh from Saterman Connect
#   Found 8 usable datapoints
# Processing row 230: Shaheen from Versa Business
#   Found 0 usable datapoints
# Processing row 231: Noel from Synergic
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 231 to 240
# Processing row 232: Monica from Boys & Girls Club of the Muskegon Lakeshore
#   Found 0 usable datapoints
# Processing row 233: Sumit from Dalwadi Hospitality Management
#   Found 3 usable datapoints
# Processing row 234: Cristian from Business Analytics Consulting Group
#   Found 4 usable datapoints
# Processing row 235: Scott from GEMM Grid & Energy Masterplanning
#   Found 1 usable datapoints
# Processing row 236: Marc from A-Street
#   Found 2 usable datapoints
# Processing row 237: Tammy from BanCal Properties
#   Found 0 usable datapoints
# Processing row 238: Jayson from BMC Consulting
#   Found 0 usable datapoints
# Processing row 239: Jack from Scope Labs
#   Found 1 usable datapoints
# Processing row 240: Scott from Dinner Table
#   Found 0 usable datapoints
# Processing row 241: Kim from Full Circle Strategies
#   Found 5 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 241 to 250
# Processing row 242: Krystian from AI Consensus
#   Found 1 usable datapoints
# Processing row 243: Juliana from ScaleTime
#   Found 7 usable datapoints
# Processing row 244: Dayana from Awtana
#   Found 5 usable datapoints
# Processing row 245: Greg from AG Collaborative
#   Found 0 usable datapoints
# Processing row 246: Steve from Eight Bit Studios
#   Found 8 usable datapoints
# Processing row 247: Alex from Streamline Books
#   Found 5 usable datapoints
# Processing row 248: Clare from New Beginnings
#   Found 5 usable datapoints
# Processing row 249: Matthew from Metanoia Catholic
#   Found 7 usable datapoints
# Processing row 250: Matt from MOHR Retail
#   Found 8 usable datapoints
# Processing row 251: Brandon from Openfield
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 251 to 260
# Processing row 252: Marc from Nucleus
#   Found 6 usable datapoints
# Processing row 253: Nathan from Ascendant
#   Found 0 usable datapoints
# Processing row 254: Christine from BenchStrength Coaching
#   Found 0 usable datapoints
# Processing row 255: Rodney from The Glasgow Group
#   Found 5 usable datapoints
# Processing row 256: Matteo from Take Flight Aviation New York
#   Found 7 usable datapoints
# Processing row 257: Doug from Paradigm Associates
#   Found 7 usable datapoints
# Processing row 258: Madeleine from Madeleine Crouch &
#   Found 1 usable datapoints
# Processing row 259: Anthony from IgnitionSystems.io
#   Found 1 usable datapoints
# Processing row 260: Kristen from Tabletop Media Group
#   Found 0 usable datapoints
# Processing row 261: Becky from Pikemann
#   Found 4 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 261 to 270
# Processing row 262: Nick from ClearSight Consulting
#   Found 4 usable datapoints
# Processing row 263: Fadi from Root Sciences
#   Found 8 usable datapoints
# Processing row 264: Justin from River City Consulting
#   Found 0 usable datapoints
# Processing row 265: John from Southern Roof Consultants
#   Found 1 usable datapoints
# Processing row 266: Jordan from ImpactEleven
#   Found 1 usable datapoints
# Processing row 267: Abigail from Climatematch Academy
#   Found 4 usable datapoints
# Processing row 268: Sterling from Syntax Talent Solutions
#   Found 2 usable datapoints
# Processing row 269: JW from Bostonian Personnel
#   Found 2 usable datapoints
# Processing row 270: Benjamin from BSB Consultants
#   Found 5 usable datapoints
# Processing row 271: Nancy from OnStrategy
#   Found 8 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 271 to 280
# Processing row 272: Karen from DMC Strategic IT
#   Found 4 usable datapoints
# Processing row 273: Bob from Millennium Business Solutions Group
#   Found 6 usable datapoints
# Processing row 274: Ricardo from Sanikey
#   Found 3 usable datapoints
# Processing row 275: Carlos from CADISA
#   Found 3 usable datapoints
# Processing row 276: Filip from NoWork.ai
#   Found 6 usable datapoints
# Processing row 277: Greg from Super Go Faster
#   Found 0 usable datapoints
# Processing row 278: Bill from Blatchford Solutions
#   Found 0 usable datapoints
# Processing row 279: Mike from Educational Consultants
#   Found 7 usable datapoints
# Processing row 280: Barry from P5
#   Found 2 usable datapoints
# Processing row 281: Sunny from Mindfulness First
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 281 to 290
# Processing row 282: Matt from The Venn Collective
#   Found 0 usable datapoints
# Processing row 283: Maryann from Healthy Teens
#   Found 4 usable datapoints
# Processing row 284: Joe from Enercon Consultants
#   Found 2 usable datapoints
# Processing row 285: Monty from MOMENTUM BILLING
#   Found 2 usable datapoints
# Processing row 286: William from AmeriTrace Damage Prevention
#   Found 1 usable datapoints
# Processing row 287: Megha from Kamet Consulting Group
#   Found 0 usable datapoints
# Processing row 288: Kelly from BDPros
#   Found 5 usable datapoints
# Processing row 289: Susan from Knowledge Tree Consulting
#   Found 4 usable datapoints
# Processing row 290: Tasha from bylittle Learning
#   Found 7 usable datapoints
# Processing row 291: Ed from Jacobs & Associates
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 291 to 300
# Processing row 292: Bill from Indivisible
#   Found 1 usable datapoints
# Processing row 293: Gina from Weinstein Realty Consultants
#   Found 1 usable datapoints
# Processing row 294: Danica from ExtendMyTeam
#   Found 5 usable datapoints
# Processing row 295: James from Ophthalmic Consultants of Connecticut P.C
#   Found 0 usable datapoints
# Processing row 296: Mike from MH Services
#   Found 1 usable datapoints
# Processing row 297: Paul from The Computer Tutor
#   Found 0 usable datapoints
# Processing row 298: Sean from Beyond the Dog
#   Found 7 usable datapoints
# Processing row 299: Brian from Current Consulting Group
#   Found 8 usable datapoints
# Processing row 300: Josh from Comp-U-Help Computers
#   Found 0 usable datapoints
# Processing row 301: Brad from Corporate Security Advisors
#   Found 7 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 301 to 310
# Processing row 302: Marilyn from Total Training Solutions
#   Found 8 usable datapoints
# Processing row 303: Kelli from Signature Builder Solutions
#   Found 0 usable datapoints
# Processing row 304: Olivier from ALLEMA
#   Found 1 usable datapoints
# Processing row 305: Tabor from Jupiter Band Instruments
#   Found 4 usable datapoints
# Processing row 306: Matt from Graduate Philadelphia
#   Found 8 usable datapoints
# Processing row 307: DJ from Marion County Commission on Youth
#   Found 8 usable datapoints
# Processing row 308: Henry from Delaware Valley Family Business Center
#   Found 0 usable datapoints
# Processing row 309: Mary from Morten Group
#   Found 0 usable datapoints
# Processing row 310: Bill from Service Strategies
#   Found 0 usable datapoints
# Processing row 311: John from Marathon Labels
#   Found 4 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 311 to 320
# Processing row 312: Travis from All Dogs Unleashed
#   Found 5 usable datapoints
# Processing row 313: Michael from Leadership Coach Group
#   Found 1 usable datapoints
# Processing row 314: Brandy from Beach Boss Influencers
#   Found 1 usable datapoints
# Processing row 315: Sara from Grey Matters
#   Found 0 usable datapoints
# Processing row 316: Eric from Flight Source International
#   Found 4 usable datapoints
# Processing row 317: Scott from Cullen Communications
#   Found 7 usable datapoints
# Processing row 318: Cheryl from Quinlan & Associates
#   Found 8 usable datapoints
# Processing row 319: Russ from Photovoice Worldwide
#   Found 3 usable datapoints
# Processing row 320: Ed from Accure for Acne
#   Found 3 usable datapoints
# Processing row 321: Rodney from Evergreen Design Group
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 321 to 330
# Processing row 322: Rick from Keller-Martin Construction
#   Found 3 usable datapoints
# Processing row 323: Grady from nocode rebels
#   Found 0 usable datapoints
# Processing row 324: Brooke from Fremont Area Chamber Of Commerce
#   Found 7 usable datapoints
# Processing row 325: Scott from Asset Optimization Consultants
#   Found 6 usable datapoints
# Processing row 326: Zachary from Advirtis
#   Found 0 usable datapoints
# Processing row 327: Jarrod from Wilcox Financial
#   Found 7 usable datapoints
# Processing row 328: Paula from Innovative Quality Solutions
#   Found 2 usable datapoints
# Processing row 329: Michael from Friedrich Watkins of Tampa
#   Found 2 usable datapoints
# Processing row 330: Raoul from Eudemian Ventures
#   Found 2 usable datapoints
# Processing row 331: Bill from Executive Search Consultants
#   Found 0 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 331 to 340
# Processing row 332: Eric from Talent Advisory Group
#   Found 0 usable datapoints
# Processing row 333: Melvin from RenewaNation
#   Found 6 usable datapoints
# Processing row 334: Donald from EDP Consulting
#   Found 0 usable datapoints
# Processing row 335: Seth from Uncommon Catalyst
#   Found 0 usable datapoints
# Processing row 336: Phil from Fabulous Fish Co
#   Found 0 usable datapoints
# Processing row 337: Candice from RADaR Analytics
#   Found 0 usable datapoints
# Processing row 338: Jeff from Barba CFO
#   Found 5 usable datapoints
# Processing row 339: Justin from Unlimited Solar
#   Found 3 usable datapoints
# Processing row 340: Ramez from Sleep Insights
#   Found 0 usable datapoints
# Processing row 341: Nancy from P5
#   Found 2 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 341 to 350
# Processing row 342: Brenda from Bottom Line Refined
#   Found 3 usable datapoints
# Processing row 343: Ralph from Sherpa Technology Group
#   Found 2 usable datapoints
# Processing row 344: Brian from Zilker Trail Consulting
#   Found 0 usable datapoints
# Processing row 345: Stephen from Real Life Trading
#   Found 6 usable datapoints
# Processing row 346: Kathryn from Half a Bubble Out
#   Found 7 usable datapoints
# Processing row 347: Angela from Prime Tax Group
#   Found 0 usable datapoints
# Processing row 348: John from Artec Machine
#   Found 0 usable datapoints
# Processing row 349: Andrew from StormwaterONE
#   Found 7 usable datapoints
# Processing row 350: Lee from Financial Management Services
#   Found 0 usable datapoints
# Processing row 351: Madhukar from iNovate Solutions
#   Found 3 usable datapoints
# Updated 10 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# Processing batch: rows 351 to 353
# Processing row 352: Carli from PAIRIN
#   Found 8 usable datapoints
# Processing row 353: Steven from Penthouse Group
#   Found 4 usable datapoints
# Processing row 354:  from
#   Found 0 usable datapoints
# Updated 3 cells in the spreadsheet
# ✅ Batch completed successfully!
#
# 🎉 Email generation completed! Successfully processed 353 rows.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 await main(start_row=1)
#
# TypeError: object NoneType can't be used in 'await' expression
