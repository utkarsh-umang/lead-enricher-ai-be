# %%
import asyncio
import re
from google.oauth2 import service_account
from googleapiclient.discovery import build
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import time

# %%
RAW_SHEET_NAME = "Sheet1" 
PROCESSED_SHEET_NAME = "Sheet2"  
CONTENT_DELIMITER = "--- NEXT CONTENT FROM HERE ---"
CATEGORIES = ["ABOUT_US", "EBOOK", "COURSES", "RECENT_BLOG", "TESTIMONIALS", "WEBINAR", "SERVICES", "PODCAST", "SHOP"]
COLUMN_TO_WRITE_URL_TO = {
	"ABOUT_US": "M", "EBOOK": "N", "COURSES": "O", "RECENT_BLOG": "P",
	"TESTIMONIALS": "Q", "WEBINAR": "R", "SERVICES": "S", "PODCAST": "T", "SHOP": "U"
}
EXTRACTION_METADATA_COLUMN = "V"
CATEGORY_THRESHOLDS = {
	"ABOUT_US": 200, "EBOOK": 200, "COURSES": 300, "RECENT_BLOG": 450, 
	"TESTIMONIALS": 100, "WEBINAR": 150, "SERVICES": 150, "PODCAST": 200, "SHOP": 100
}
OPENAI_API_KEY = ""
SHEET_URL = "https://docs.google.com/spreadsheets/d/1k5MwqNbHKRi1yXFfy-ZBsqy1pqOkkyKxGN1JBydRneo/edit?gid=1830149924#gid=1830149924"
CREDENTIALS_FILE = "data/url-to-email-445616-cebe4868914f.json"  
PROMPT_TEMPLATES = {
		"RECENT_BLOG": """
You are provided with multiple blog posts. Your task is to evaluate each post based on the following criteria and select the one with the highest total score. Then, output **only** the content text of the selected blog post. Do not include any explanations, scores, rankings, metadata, or additional information.

**Evaluation Criteria:**
1. *Recency*: Score based on how recently the post was published, using the publication date provided.
2. *Relevance to Prospect's Industry*: Score based on how relevant the content is to the specified industry or keywords, using the excerpt provided.
3. *Post Length*: Score based on the word count, with a minimum of 200 words.

**Scoring Guidelines**:
- *Recency*:
	- Within the last month: 10
	- 1-3 months ago: 8
	- 3-6 months ago: 6
	- 6-12 months ago: 4
	- Over 12 months ago: 2
- *Relevance to Prospect's Industry*:
	- Highly relevant (multiple keywords or strong topic alignment): 10
	- Moderately relevant (some keywords or partial alignment): 7
	- Slightly relevant (few keywords or weak alignment): 5
	- Not relevant: 0
- *Post Length*:
	- Less than 200 words: 0
	- 200-500 words: 5
	- 500-1000 words: 7
	- 1000-2000 words: 9
	- 2000+ words: 10

**Final Output**:
- Output **only** the content text of the blog post with the highest total score.
- Do **not** include any explanations, scores, rankings, metadata (e.g., "Content length", "Line count", "Word Count"), or any other information.
- Do **not** mention other posts or provide any additional context.

{content}
"""
}

# %%
# Global rate limiter to track API requests across all categories
class RateLimiter:
    def __init__(self, max_requests_per_minute=60):
        self.max_requests_per_minute = max_requests_per_minute
        self.request_times = []
        
    async def wait_if_needed(self):
        """Wait if we're approaching the rate limit"""
        now = time.time()
        
        # Remove timestamps older than 1 minute
        self.request_times = [t for t in self.request_times if now - t < 60]
        
        # If we're at capacity, wait until we have space
        if len(self.request_times) >= self.max_requests_per_minute:
            oldest = min(self.request_times)
            wait_time = 60 - (now - oldest) + 0.1  # Add a small buffer
            if wait_time > 0:
                print(f"   ⏱️ Rate limit approaching: waiting {wait_time:.2f} seconds")
                await asyncio.sleep(wait_time)
        
        # Add the current request
        self.request_times.append(time.time())

# GoogleSheetsManager class for API interactions
class GoogleSheetsManager:
    def __init__(self, credentials_file):
        print(f"🔧 Initializing GoogleSheetsManager with credentials: {credentials_file}")
        scopes = ['https://www.googleapis.com/auth/spreadsheets']
        creds = service_account.Credentials.from_service_account_file(credentials_file, scopes=scopes)
        self.service = build('sheets', 'v4', credentials=creds)
        print("✅ Google Sheets service initialized successfully")

    def extract_spreadsheet_id(self, sheet_url):
        print(f"🔍 Extracting spreadsheet ID from URL: {sheet_url}")
        pattern = r'/spreadsheets/d/([a-zA-Z0-9-_]+)'
        match = re.search(pattern, sheet_url)
        if match:
            spreadsheet_id = match.group(1)
            print(f"✅ Extracted spreadsheet ID: {spreadsheet_id}")
            return spreadsheet_id
        raise ValueError(f"Invalid Google Sheet URL: {sheet_url}")

# Parse content into pieces based on delimiter and metadata
def parse_content_pieces(content, expected_count, category, row_num):
    print(f"\n📝 Parsing content for {category} (Row {row_num})")
    print(f"   Expected count: {expected_count}")
    print(f"   Content length: {len(content) if content else 0} characters")
    
    if not content or not content.strip():
        print("   ⚠️  No content to parse")
        return []
    
    cleaned_content = content.strip()
    delimiters_to_try = [
        CONTENT_DELIMITER,
        CONTENT_DELIMITER.strip(),
        "-----NEXT CONTENT FROM HERE-----",
        "--- NEXT CONTENT FROM HERE ---"
        "--- --NEXT CONTENT FROM HERE-----",
        "-----NEXT CONTENT FROM HERE--- --",
    ]
    
    pieces = None
    delimiter_used = None
    
    print(f"   🔍 Trying {len(delimiters_to_try)} different delimiters...")
    for i, delimiter in enumerate(delimiters_to_try):
        if delimiter in cleaned_content:
            pieces = cleaned_content.split(delimiter)
            delimiter_used = delimiter
            print(f"   ✅ Found delimiter #{i+1}: '{delimiter[:30]}...'")
            break
    
    if pieces is None:
        print("   ℹ️  No delimiter found, treating as single piece")
        pieces = [cleaned_content]
    else:
        print(f"   📊 Split into {len(pieces)} raw pieces")
    
    cleaned_pieces = [piece.strip() for piece in pieces if piece.strip()]
    print(f"   🧹 After cleaning: {len(cleaned_pieces)} valid pieces")
    
    for i, piece in enumerate(cleaned_pieces):
        print(f"      Piece {i+1}: {len(piece)} chars, {len(piece.split())} words")
    
    if expected_count == 1 and len(cleaned_pieces) == 1:
        print("   ✅ Expected 1, got 1 - returning as is")
        return cleaned_pieces
    elif expected_count > 1:
        if len(cleaned_pieces) >= expected_count:
            result = cleaned_pieces[:expected_count]
            print(f"   ✂️  Taking first {expected_count} pieces")
            return result
        else:
            print(f"   ⚠️  Expected {expected_count}, only got {len(cleaned_pieces)}")
            return cleaned_pieces
    else:
        print(f"   ↩️  Returning all {len(cleaned_pieces)} pieces")
        return cleaned_pieces

# Read and organize data from the input sheet
async def read_data_from_sheet(spreadsheet_id, sheet_mgr, categories):
    print(f"\n📖 Reading data from spreadsheet: {spreadsheet_id}")
    print(f"   Categories to process: {categories}")
    
    category_columns = {cat: COLUMN_TO_WRITE_URL_TO.get(cat.upper()) for cat in categories}
    print(f"   Column mapping: {category_columns}")
    
    if any(col is None for col in category_columns.values()):
        missing = [cat for cat, col in category_columns.items() if col is None]
        print(f"   ❌ Missing columns for categories: {missing}")
        raise ValueError("One or more categories do not have a defined column in COLUMN_TO_WRITE_URL_TO")
    
    metadata_column = EXTRACTION_METADATA_COLUMN
    ranges = [f"{RAW_SHEET_NAME}!{col}2:{col}" for col in category_columns.values()] + [f"{RAW_SHEET_NAME}!{metadata_column}2:{metadata_column}"]
    print(f"   📋 Reading ranges: {ranges}")
    
    try:
        response = await asyncio.to_thread(
            sheet_mgr.service.spreadsheets().values().batchGet(spreadsheetId=spreadsheet_id, ranges=ranges).execute
        )
        print("   ✅ Successfully read data from Google Sheets")
    except Exception as e:
        print(f"   ❌ Failed to read data: {str(e)}")
        raise RuntimeError(f"Failed to read data from spreadsheet {spreadsheet_id}: {str(e)}")
    
    value_ranges = response.get('valueRanges', [])
    print(f"   📊 Got {len(value_ranges)} value ranges")
    
    column_data = {}
    for i, col in enumerate(category_columns.values()):
        column_data[col] = value_ranges[i].get('values', [])
        print(f"   Column {col}: {len(column_data[col])} rows")
    
    column_data[metadata_column] = value_ranges[-1].get('values', [])
    print(f"   Metadata column {metadata_column}: {len(column_data[metadata_column])} rows")
    
    num_rows = max(len(values) for values in column_data.values()) if column_data else 0
    print(f"   📏 Total rows to process: {num_rows}")
    
    data = []
    for i in range(num_rows):
        print(f"\n   🔍 Processing row {i+2}...")
        row_data = {}
        
        # Get metadata
        metadata_value = column_data[metadata_column][i][0] if i < len(column_data[metadata_column]) and column_data[metadata_column][i] else ''
        print(f"      Metadata: '{metadata_value}'")
        
        # Parse category counts
        category_n_dict = {}
        for part in metadata_value.split(','):
            if '=' in part:
                cat, n_str = part.split('=', 1)
                try:
                    n = int(n_str.strip())
                    category_n_dict[cat.strip().upper()] = n
                    print(f"      Found: {cat.strip().upper()} = {n}")
                except ValueError:
                    print(f"      ⚠️  Invalid count for: {part}")
                    pass
        
        print(f"      Category counts: {category_n_dict}")
        
        # Process each category
        for category in categories:
            category_upper = category.upper()
            print(f"      🔍 Checking category: {category_upper}")
            
            if category_upper in category_n_dict and category_n_dict[category_upper] > 0:
                print(f"         ✅ Count > 0, processing...")
                col = category_columns[category]
                content = column_data[col][i][0] if i < len(column_data[col]) and column_data[col][i] else ''
                expected_count = category_n_dict[category_upper]
                
                print(f"         Content preview: '{content[:100]}...' ({len(content)} chars)")
                
                parsed_pieces = parse_content_pieces(content, expected_count, category, i+2)
                if parsed_pieces:
                    row_data[category] = parsed_pieces
                    print(f"         ✅ Added {len(parsed_pieces)} pieces to row data")
                else:
                    print(f"         ⚠️  No valid pieces found")
            else:
                print(f"         ❌ Skipping (count = {category_n_dict.get(category_upper, 0)})")
        
        data.append(row_data)
        print(f"      Row {i+2} final data: {list(row_data.keys())}")
    
    print(f"✅ Data reading complete. Processed {len(data)} rows")
    return data

# Format RECENT_BLOG content for AI processing
def explore_all_content1(data, row_number, category):
    print(f"\n🤖 Formatting content for AI processing...")
    print(f"   Row: {row_number}, Category: {category}")
    
    try:
        row_data = data[row_number - 2]
        print(f"   Row data keys: {list(row_data.keys())}")
        
        if category in row_data:
            pieces = row_data[category]
            print(f"   Found {len(pieces)} pieces to format")
            
            output = []
            for idx, content in enumerate(pieces, start=1):
                print(f"   Formatting piece {idx}: {len(content)} chars")
                output.append(f"*Blog Post {idx}*:")
                output.append(content)
                output.append("")
                output.append(f"Content length: {len(content)} characters")
                output.append(f"Line count: {len(content.splitlines())}")
                output.append(f"Word Count: {len(content.split())}")
            
            formatted_output = "\n".join(output)
            print(f"   ✅ Formatted output: {len(formatted_output)} total chars")
            return formatted_output
        else:
            error_msg = f"Error: Category '{category}' not found in row {row_number}."
            print(f"   ❌ {error_msg}")
            return error_msg
    except IndexError:
        error_msg = f"Error: Row {row_number} not found. Available rows: 2 to {len(data) + 1}"
        print(f"   ❌ {error_msg}")
        return error_msg

# Set up LangChain pipeline for AI processing
def create_chain(category):
    print(f"🔗 Creating LangChain pipeline for category: {category}")
    
    if category not in PROMPT_TEMPLATES:
        error_msg = f"No prompt defined for category {category}"
        print(f"   ❌ {error_msg}")
        raise ValueError(error_msg)
    
    prompt = PromptTemplate(
        input_variables=["content"],
        template=PROMPT_TEMPLATES[category]
    )
    
    print(f"   📝 Using prompt template for {category}")
    print(f"   🤖 Initializing ChatOpenAI with GPT-4")
    
    llm = ChatOpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)
    chain = prompt | llm | StrOutputParser()
    
    print(f"   ✅ Chain created successfully")
    return chain

# Process RECENT_BLOG row with AI
async def process_row_with_langchain(content_output, category):
    print(f"\n🚀 Processing with AI (LangChain)...")
    print(f"   Category: {category}")
    print(f"   Input length: {len(content_output)} characters")
    
    chain = create_chain(category)
    
    if not content_output.strip() or "Error:" in content_output:
        error_msg = f"No valid content provided for {category}"
        print(f"   ❌ {error_msg}")
        return error_msg
    
    try:
        print("   🔄 Sending to AI...")
        response = await chain.ainvoke({"content": content_output})
        print(f"   ✅ AI processing successful!")
        print(f"   📤 Response length: {len(response)} characters")
        print(f"   📤 Response preview: '{response[:200]}...'")
        return response
    except Exception as e:
        error_msg = f"Error processing row for {category}: {str(e)}"
        print(f"   ❌ {error_msg}")
        return f"Error processing row for {category}"

# Modified write_batch function with improved rate limiting
async def write_batch_with_rate_limit(sheet_mgr, spreadsheet_id, range_name, values, batch_num, category, 
                                     max_retries=3, rate_limiter=None):
    """Write a batch to Google Sheets with retry logic and rate limiting."""
    print(f"\n   📤 Writing batch #{batch_num} to sheet range: {range_name}")
    print(f"   📊 Writing {len(values)} values")
    
    retry_count = 0
    backoff_time = 1  # Start with 1 second
    
    while retry_count <= max_retries:
        try:
            # Check rate limits before making the request
            if rate_limiter:
                await rate_limiter.wait_if_needed()
            
            sheet_mgr.service.spreadsheets().values().update(
                spreadsheetId=spreadsheet_id,
                range=range_name,
                valueInputOption='RAW',
                body={'values': values}
            ).execute()
            
            print(f"   ✅ Successfully wrote batch #{batch_num} for {category}")
            return True
            
        except Exception as e:
            retry_count += 1
            is_quota_error = "quota" in str(e).lower() or "rate" in str(e).lower()
            
            if is_quota_error and retry_count <= max_retries:
                # Exponential backoff for quota errors
                print(f"   ⚠️ Rate limit exceeded on attempt {retry_count}/{max_retries}")
                print(f"   ⏱️ Backing off for {backoff_time} seconds...")
                await asyncio.sleep(backoff_time)
                backoff_time *= 2  # Exponential backoff
                print(f"   🔄 Retrying...")
            else:
                # Other error or max retries reached
                print(f"   ❌ Failed to write batch #{batch_num} for {category}: {str(e)}")
                if retry_count > max_retries:
                    print(f"   ❌ Max retries ({max_retries}) exceeded")
                return False
    
    return False

# Process a category column according to the algorithm
async def process_category(data, category, sheet_mgr, spreadsheet_id, start_row=2, batch_size=5, max_retries=3, rate_limiter=None):
    print(f"\n🏭 Processing category: {category}")
    print(f"   Starting from row: {start_row}")
    print(f"   Batch size: {batch_size}")
    
    column = COLUMN_TO_WRITE_URL_TO[category.upper()]
    print(f"   Target column: {column}")
    
    values = []
    current_batch = 0
    
    # Calculate the range of rows to process based on start_row
    data_start_idx = start_row - 2  # Convert sheet row to data array index
    end_row = len(data) + 2
    
    print(f"   Processing sheet rows {start_row} to {end_row-1}")
    print(f"   Data array indices {data_start_idx} to {len(data)-1}")
    
    for row_idx in range(start_row, end_row):
        data_idx = row_idx - 2  # Convert sheet row to data array index
        
        # Check if we have data for this row
        if data_idx >= len(data):
            print(f"      ⚠️ Row {row_idx} exceeds available data, stopping")
            break
            
        print(f"\n   📋 Processing row {row_idx} (data index {data_idx})...")
        row_data = data[data_idx]
        pieces = row_data.get(category, [])
        
        print(f"      Found {len(pieces)} pieces for {category}")
        
        # [existing processing logic remains the same]
        if not pieces:
            output = "no content"
            print(f"      ❌ No pieces found -> '{output}'")
        elif len(pieces) == 1:
            output = pieces[0]
            print(f"      📋 Single piece -> copying directly ({len(output)} chars)")
        else:
            print(f"      🔄 Multiple pieces ({len(pieces)}) - applying processing logic...")
            
            if category == "RECENT_BLOG":
                print(f"         🤖 RECENT_BLOG category -> AI processing")
                content_output = explore_all_content1(data, row_idx, category)
                
                if "Error:" in content_output:
                    output = "No valid content provided"
                    print(f"         ❌ Error in content formatting -> '{output}'")
                else:
                    print(f"         🚀 Sending to AI processing...")
                    output = await process_row_with_langchain(content_output, category)
                    print(f"         ✅ AI processing complete")
            else:
                # Non-blog categories logic
                print(f"         📏 Non-blog category -> length-based selection")
                threshold = CATEGORY_THRESHOLDS.get(category.upper(), 0)
                print(f"         📊 Word threshold: {threshold}")
                
                candidates = [p for p in pieces if len(p.split()) >= threshold]
                print(f"         🎯 Candidates meeting threshold: {len(candidates)}")
                
                if candidates:
                    output = max(candidates, key=lambda p: len(p.split()))
                    print(f"         ✅ Selected longest candidate: {len(output.split())} words")
                else:
                    output = max(pieces, key=lambda p: len(p.split()))
                    print(f"         ⚠️  No candidates met threshold, selected longest: {len(output.split())} words")
        
        values.append([output])
        print(f"      ✅ Row {row_idx} output: {len(output)} chars")
        
        # Check if batch is complete
        if len(values) >= batch_size:
            # Calculate the range for the current batch
            batch_start_row = start_row + current_batch * batch_size
            batch_end_row = batch_start_row + len(values) - 1
            batch_range = f"{PROCESSED_SHEET_NAME}!{column}{batch_start_row}:{column}{batch_end_row}"
            
            print(f"      📤 Writing batch to range: {batch_range}")
            
            # Write the current batch with retry and rate limiting
            await write_batch_with_rate_limit(
                sheet_mgr=sheet_mgr,
                spreadsheet_id=spreadsheet_id,
                range_name=batch_range,
                values=values,
                batch_num=current_batch+1,
                category=category,
                max_retries=max_retries,
                rate_limiter=rate_limiter
            )
            
            # Reset for next batch
            values = []
            current_batch += 1
    
    # Write any remaining rows
    if values:
        batch_start_row = start_row + current_batch * batch_size
        batch_end_row = batch_start_row + len(values) - 1
        batch_range = f"{PROCESSED_SHEET_NAME}!{column}{batch_start_row}:{column}{batch_end_row}"
        
        print(f"   📤 Writing final batch to range: {batch_range}")
        
        await write_batch_with_rate_limit(
            sheet_mgr=sheet_mgr,
            spreadsheet_id=spreadsheet_id,
            range_name=batch_range,
            values=values,
            batch_num="final",
            category=category,
            max_retries=max_retries,
            rate_limiter=rate_limiter
        )

# %%
async def main(regular_batch_size=100, blog_batch_size=5, max_retries=3, start_row=2):
    print("🚀 Starting Content Processing Pipeline")
    print("=" * 50)
    print(f"Regular batch size: {regular_batch_size}, Blog batch size: {blog_batch_size}")
    print(f"Max retries: {max_retries}")
    print(f"Starting from row: {start_row}")
    
    # Create a global rate limiter (target 50 requests/min to stay comfortably under the 60/min limit)
    rate_limiter = RateLimiter(max_requests_per_minute=50)
    
    try:
        print("\n📋 Step 1: Initialize Google Sheets Manager")
        sheet_mgr = GoogleSheetsManager(CREDENTIALS_FILE)
        
        print("\n📋 Step 2: Extract Spreadsheet ID")
        spreadsheet_id = sheet_mgr.extract_spreadsheet_id(SHEET_URL)
        
        print("\n📋 Step 3: Read Data from Sheet")
        data = await read_data_from_sheet(spreadsheet_id, sheet_mgr, CATEGORIES)
        
        # Validate start_row
        max_available_row = len(data) + 1  # +1 because data starts from row 2
        if start_row > max_available_row:
            print(f"❌ Error: start_row ({start_row}) exceeds available data (max row: {max_available_row})")
            return
        
        print(f"\n📋 Step 4: Process Categories ({len(CATEGORIES)} total)")
        print(f"   Available data rows: 2 to {max_available_row}")
        print(f"   Processing rows: {start_row} to {max_available_row}")
        
        # Separate categories into regular and blog
        regular_categories = [cat for cat in CATEGORIES if cat != "RECENT_BLOG"]
        blog_category = "RECENT_BLOG" if "RECENT_BLOG" in CATEGORIES else None
        
        # Process regular categories first with larger batch size
        for i, category in enumerate(regular_categories, 1):
            print(f"\n🔄 Processing regular category {i}/{len(regular_categories)}: {category}")
            await process_category(
                data, 
                category, 
                sheet_mgr, 
                spreadsheet_id, 
                start_row=start_row,
                batch_size=regular_batch_size, 
                max_retries=max_retries,
                rate_limiter=rate_limiter
            )
            print(f"✅ Completed regular category: {category}")
        
        # Process blog category last with smaller batch size
        if blog_category:
            print(f"\n🔄 Processing blog category: {blog_category} (with smaller batch size)")
            await process_category(
                data, 
                blog_category, 
                sheet_mgr, 
                spreadsheet_id, 
                start_row=start_row,
                batch_size=blog_batch_size, 
                max_retries=max_retries,
                rate_limiter=rate_limiter
            )
            print(f"✅ Completed blog category: {blog_category}")
        
        print("\n🎉 Pipeline completed successfully!")
        
    except Exception as e:
        print(f"\n💥 Pipeline failed with error: {str(e)}")
        import traceback
        print("📋 Full traceback:")
        traceback.print_exc()

# %%
await main(regular_batch_size=100, blog_batch_size=5, start_row=197)
# Out:
# 🚀 Starting Content Processing Pipeline
# ==================================================
# Regular batch size: 100, Blog batch size: 5
# Max retries: 3
# Starting from row: 197
#
# 📋 Step 1: Initialize Google Sheets Manager
# 🔧 Initializing GoogleSheetsManager with credentials: data/url-to-email-445616-cebe4868914f.json
# ✅ Google Sheets service initialized successfully
#
# 📋 Step 2: Extract Spreadsheet ID
# 🔍 Extracting spreadsheet ID from URL: https://docs.google.com/spreadsheets/d/1k5MwqNbHKRi1yXFfy-ZBsqy1pqOkkyKxGN1JBydRneo/edit?gid=1830149924#gid=1830149924
# ✅ Extracted spreadsheet ID: 1k5MwqNbHKRi1yXFfy-ZBsqy1pqOkkyKxGN1JBydRneo
#
# 📋 Step 3: Read Data from Sheet
#
# 📖 Reading data from spreadsheet: 1k5MwqNbHKRi1yXFfy-ZBsqy1pqOkkyKxGN1JBydRneo
#    Categories to process: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Column mapping: {'ABOUT_US': 'M', 'EBOOK': 'N', 'COURSES': 'O', 'RECENT_BLOG': 'P', 'TESTIMONIALS': 'Q', 'WEBINAR': 'R', 'SERVICES': 'S', 'PODCAST': 'T', 'SHOP': 'U'}
#    📋 Reading ranges: ['Sheet1!M2:M', 'Sheet1!N2:N', 'Sheet1!O2:O', 'Sheet1!P2:P', 'Sheet1!Q2:Q', 'Sheet1!R2:R', 'Sheet1!S2:S', 'Sheet1!T2:T', 'Sheet1!U2:U', 'Sheet1!V2:V']
#    ✅ Successfully read data from Google Sheets
#    📊 Got 10 value ranges
#    Column M: 1002 rows
#    Column N: 1002 rows
#    Column O: 1002 rows
#    Column P: 1002 rows
#    Column Q: 1002 rows
#    Column R: 1002 rows
#    Column S: 1002 rows
#    Column T: 1002 rows
#    Column U: 1002 rows
#    Metadata column V: 1002 rows
#    📏 Total rows to process: 1002
#
#    🔍 Processing row 2...
#       Metadata: 'ABOUT_US=8,EBOOK=0,COURSES=10,RECENT_BLOG=5,TESTIMONIALS=0,WEBINAR=10,SERVICES=8,PODCAST=7,SHOP=0'
#       Found: ABOUT_US = 8
#       Found: EBOOK = 0
#       Found: COURSES = 10
#       Found: RECENT_BLOG = 5
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 10
#       Found: SERVICES = 8
#       Found: PODCAST = 7
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 8, 'EBOOK': 0, 'COURSES': 10, 'RECENT_BLOG': 5, 'TESTIMONIALS': 0, 'WEBINAR': 10, 'SERVICES': 8, 'PODCAST': 7, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'Why outsource to ACG Professionals?
# With ACG, you have the confidence that experienced professionals...' (12906 chars)
#
# 📝 Parsing content for ABOUT_US (Row 2)
#    Expected count: 8
#    Content length: 12906 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 8 raw pieces
#    🧹 After cleaning: 8 valid pieces
#       Piece 1: 1357 chars, 216 words
#       Piece 2: 547 chars, 93 words
#       Piece 3: 3444 chars, 524 words
#       Piece 4: 632 chars, 90 words
#       Piece 5: 1881 chars, 268 words
#       Piece 6: 1948 chars, 275 words
#       Piece 7: 1612 chars, 231 words
#       Piece 8: 1261 chars, 171 words
#    ✂️  Taking first 8 pieces
#          ✅ Added 8 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'ACG Boot Camp
# Covers everything you need to know about the industry’s most widely used software.
# ACG...' (16823 chars)
#
# 📝 Parsing content for COURSES (Row 2)
#    Expected count: 10
#    Content length: 16823 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 1605 chars, 244 words
#       Piece 2: 404 chars, 82 words
#       Piece 3: 514 chars, 80 words
#       Piece 4: 1345 chars, 201 words
#       Piece 5: 3195 chars, 500 words
#       Piece 6: 1897 chars, 282 words
#       Piece 7: 1884 chars, 280 words
#       Piece 8: 1897 chars, 282 words
#       Piece 9: 1897 chars, 282 words
#       Piece 10: 1897 chars, 282 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'Interview and Resume Tips
# |
# Networking Tips and Events
# |
# News
# Quality Internships – Look No Further ...' (9314 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 2)
#    Expected count: 5
#    Content length: 9314 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 5 raw pieces
#    🧹 After cleaning: 5 valid pieces
#       Piece 1: 646 chars, 110 words
#       Piece 2: 4193 chars, 695 words
#       Piece 3: 1044 chars, 170 words
#       Piece 4: 2421 chars, 421 words
#       Piece 5: 882 chars, 150 words
#    ✂️  Taking first 5 pieces
#          ✅ Added 5 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Upcoming Events
# No events in this category --- NEXT CONTENT FROM HERE --- Upcoming Events
# DCF Traini...' (4488 chars)
#
# 📝 Parsing content for WEBINAR (Row 2)
#    Expected count: 10
#    Content length: 4488 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 42 chars, 7 words
#       Piece 2: 370 chars, 74 words
#       Piece 3: 42 chars, 7 words
#       Piece 4: 42 chars, 7 words
#       Piece 5: 265 chars, 41 words
#       Piece 6: 7 chars, 2 words
#       Piece 7: 36 chars, 7 words
#       Piece 8: 37 chars, 6 words
#       Piece 9: 404 chars, 82 words
#       Piece 10: 2955 chars, 521 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Software Selection & Implementation
# Lease Administration & Abstraction
# Evaluation of Current Practic...' (11362 chars)
#
# 📝 Parsing content for SERVICES (Row 2)
#    Expected count: 8
#    Content length: 11362 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 8 raw pieces
#    🧹 After cleaning: 8 valid pieces
#       Piece 1: 1283 chars, 195 words
#       Piece 2: 1818 chars, 247 words
#       Piece 3: 514 chars, 80 words
#       Piece 4: 1394 chars, 198 words
#       Piece 5: 1702 chars, 241 words
#       Piece 6: 1377 chars, 196 words
#       Piece 7: 1383 chars, 194 words
#       Piece 8: 1667 chars, 269 words
#    ✂️  Taking first 8 pieces
#          ✅ Added 8 pieces to row data
#       🔍 Checking category: PODCAST
#          ✅ Count > 0, processing...
#          Content preview: 'Interview and Resume Tips
# Don’t Worry, Be Happy
# By
# Todd Zeldin
# I recently interviewed a candidate wh...' (15643 chars)
#
# 📝 Parsing content for PODCAST (Row 2)
#    Expected count: 7
#    Content length: 15643 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 7 raw pieces
#    🧹 After cleaning: 7 valid pieces
#       Piece 1: 4002 chars, 705 words
#       Piece 2: 3929 chars, 696 words
#       Piece 3: 4333 chars, 733 words
#       Piece 4: 189 chars, 32 words
#       Piece 5: 821 chars, 131 words
#       Piece 6: 1110 chars, 173 words
#       Piece 7: 1067 chars, 176 words
#    ✂️  Taking first 7 pieces
#          ✅ Added 7 pieces to row data
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 2 final data: ['ABOUT_US', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST']
#
#    🔍 Processing row 3...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=1,TESTIMONIALS=0,WEBINAR=1,SERVICES=1,PODCAST=1,SHOP=9'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 1
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 1
#       Found: SERVICES = 1
#       Found: PODCAST = 1
#       Found: SHOP = 9
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 1, 'TESTIMONIALS': 0, 'WEBINAR': 1, 'SERVICES': 1, 'PODCAST': 1, 'SHOP': 9}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'Pattern’s Partnership with Society6 Featured As A Shopify Case Study
# August 20, 2025
# August 20, 2025...' (116 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 3)
#    Expected count: 1
#    Content length: 116 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 116 chars, 18 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Pattern-Logo-light
# Work
# Services
# About Us
# News
# Contact
# Work
# Services
# About Us
# News
# Contact
# OLIVE & J...' (13235 chars)
#
# 📝 Parsing content for WEBINAR (Row 3)
#    Expected count: 1
#    Content length: 13235 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 13235 chars, 2077 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Pattern-Logo-light
# Work
# Services
# About Us
# News
# Contact
# Work
# Services
# About Us
# News
# Contact
# SERVICE O...' (3482 chars)
#
# 📝 Parsing content for SERVICES (Row 3)
#    Expected count: 1
#    Content length: 3482 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 3482 chars, 552 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: PODCAST
#          ✅ Count > 0, processing...
#          Content preview: 'Pattern-Logo-light
# Work
# Services
# About Us
# News
# Contact
# Work
# Services
# About Us
# News
# Contact
# Awards
# Pa...' (4480 chars)
#
# 📝 Parsing content for PODCAST (Row 3)
#    Expected count: 1
#    Content length: 4480 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 4480 chars, 735 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'Pattern-Logo-light
# Work
# Services
# About Us
# News
# Contact
# Work
# Services
# About Us
# News
# Contact
# OUR WORK:...' (41845 chars)
#
# 📝 Parsing content for SHOP (Row 3)
#    Expected count: 9
#    Content length: 41845 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 8 raw pieces
#    🧹 After cleaning: 8 valid pieces
#       Piece 1: 2006 chars, 339 words
#       Piece 2: 1717 chars, 293 words
#       Piece 3: 3400 chars, 541 words
#       Piece 4: 3558 chars, 567 words
#       Piece 5: 6667 chars, 1097 words
#       Piece 6: 13542 chars, 2142 words
#       Piece 7: 5442 chars, 870 words
#       Piece 8: 5289 chars, 845 words
#    ⚠️  Expected 9, only got 8
#          ✅ Added 8 pieces to row data
#       Row 3 final data: ['RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#
#    🔍 Processing row 4...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 4 final data: []
#
#    🔍 Processing row 5...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=1,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 1
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 1, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Strategic
# Hiring Solutions
# At FIRST STAFFING GROUP, we pride ourselves on offering comprehensive rec...' (1539 chars)
#
# 📝 Parsing content for SERVICES (Row 5)
#    Expected count: 1
#    Content length: 1539 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 1539 chars, 216 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 5 final data: ['SERVICES']
#
#    🔍 Processing row 6...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 6 final data: []
#
#    🔍 Processing row 7...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 7 final data: []
#
#    🔍 Processing row 8...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 8 final data: []
#
#    🔍 Processing row 9...
#       Metadata: 'ABOUT_US=2,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=9,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 2
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 9
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 2, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 9, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'About Pivot Path Solutions
# Corporate Overview:
# Based in the National Capital Region, Pivot Path Solu...' (6613 chars)
#
# 📝 Parsing content for ABOUT_US (Row 9)
#    Expected count: 2
#    Content length: 6613 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 4068 chars, 562 words
#       Piece 2: 2513 chars, 342 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Eddie C. Riely
# COO
# Eddie is a retired Federal Executive and the COO of Pivot Path Solutions. He is r...' (17157 chars)
#
# 📝 Parsing content for SERVICES (Row 9)
#    Expected count: 9
#    Content length: 17157 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 1282 chars, 189 words
#       Piece 2: 1275 chars, 190 words
#       Piece 3: 2030 chars, 289 words
#       Piece 4: 4068 chars, 562 words
#       Piece 5: 2614 chars, 351 words
#       Piece 6: 572 chars, 63 words
#       Piece 7: 2411 chars, 334 words
#       Piece 8: 141 chars, 4 words
#       Piece 9: 2508 chars, 365 words
#    ✂️  Taking first 9 pieces
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 9 final data: ['ABOUT_US', 'SERVICES']
#
#    🔍 Processing row 10...
#       Metadata: 'ABOUT_US=8,EBOOK=0,COURSES=9,RECENT_BLOG=4,TESTIMONIALS=0,WEBINAR=9,SERVICES=3,PODCAST=10,SHOP=4'
#       Found: ABOUT_US = 8
#       Found: EBOOK = 0
#       Found: COURSES = 9
#       Found: RECENT_BLOG = 4
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 9
#       Found: SERVICES = 3
#       Found: PODCAST = 10
#       Found: SHOP = 4
#       Category counts: {'ABOUT_US': 8, 'EBOOK': 0, 'COURSES': 9, 'RECENT_BLOG': 4, 'TESTIMONIALS': 0, 'WEBINAR': 9, 'SERVICES': 3, 'PODCAST': 10, 'SHOP': 4}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'Home
# Instructors
# Lessons
# Adult Lessons
# Junior Lessons
# Junior Academy
# PGA Camps
# PGA Junior League
# Tin...' (18089 chars)
#
# 📝 Parsing content for ABOUT_US (Row 10)
#    Expected count: 8
#    Content length: 18089 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 8 raw pieces
#    🧹 After cleaning: 8 valid pieces
#       Piece 1: 836 chars, 125 words
#       Piece 2: 13098 chars, 2305 words
#       Piece 3: 499 chars, 94 words
#       Piece 4: 82 chars, 13 words
#       Piece 5: 836 chars, 125 words
#       Piece 6: 842 chars, 161 words
#       Piece 7: 836 chars, 125 words
#       Piece 8: 836 chars, 125 words
#    ✂️  Taking first 8 pieces
#          ✅ Added 8 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Fall 2020
# After School Program
# Flexible programs to fit your busy distanced learning schedule.
# Our C...' (29846 chars)
#
# 📝 Parsing content for COURSES (Row 10)
#    Expected count: 9
#    Content length: 29846 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 13441 chars, 2256 words
#       Piece 2: 836 chars, 125 words
#       Piece 3: 13268 chars, 2222 words
#       Piece 4: 932 chars, 165 words
#       Piece 5: 238 chars, 37 words
#       Piece 6: 273 chars, 45 words
#       Piece 7: 163 chars, 29 words
#       Piece 8: 212 chars, 38 words
#       Piece 9: 227 chars, 38 words
#    ✂️  Taking first 9 pieces
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'Skip to content
# Silicon Valley Golf Performance Center
# Home
# Instructors
# Lessons
# Adult Lessons
# Junior...' (47029 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 10)
#    Expected count: 4
#    Content length: 47029 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 4 raw pieces
#    🧹 After cleaning: 4 valid pieces
#       Piece 1: 15399 chars, 2720 words
#       Piece 2: 15399 chars, 2720 words
#       Piece 3: 736 chars, 139 words
#       Piece 4: 15399 chars, 2720 words
#    ✂️  Taking first 4 pieces
#          ✅ Added 4 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Home
# Instructors
# Lessons
# Adult Lessons
# Junior Lessons
# Junior Academy
# PGA Camps
# PGA Junior League
# Tin...' (11101 chars)
#
# 📝 Parsing content for WEBINAR (Row 10)
#    Expected count: 9
#    Content length: 11101 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 9 raw pieces
#    🧹 After cleaning: 9 valid pieces
#       Piece 1: 836 chars, 125 words
#       Piece 2: 1394 chars, 249 words
#       Piece 3: 1394 chars, 249 words
#       Piece 4: 1394 chars, 249 words
#       Piece 5: 1394 chars, 249 words
#       Piece 6: 1367 chars, 243 words
#       Piece 7: 836 chars, 125 words
#       Piece 8: 836 chars, 125 words
#       Piece 9: 1394 chars, 249 words
#    ✂️  Taking first 9 pieces
#          ✅ Added 9 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Why You Should Practice
# Make Practicing Fun
# Recently, Kim got the opportunity to speak to the PWGA a...' (556 chars)
#
# 📝 Parsing content for SERVICES (Row 10)
#    Expected count: 3
#    Content length: 556 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 3 raw pieces
#    🧹 After cleaning: 3 valid pieces
#       Piece 1: 341 chars, 57 words
#       Piece 2: 80 chars, 13 words
#       Piece 3: 71 chars, 12 words
#    ✂️  Taking first 3 pieces
#          ✅ Added 3 pieces to row data
#       🔍 Checking category: PODCAST
#          ✅ Count > 0, processing...
#          Content preview: '« All Events
# Beginning Lesson Series I (8/24 – 9/28)
# September 7 @ 9:00 am
# -
# 10:00 am
# |
# Recurring Ev...' (30867 chars)
#
# 📝 Parsing content for PODCAST (Row 10)
#    Expected count: 10
#    Content length: 30867 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 2881 chars, 487 words
#       Piece 2: 2952 chars, 502 words
#       Piece 3: 2958 chars, 514 words
#       Piece 4: 2977 chars, 511 words
#       Piece 5: 2991 chars, 514 words
#       Piece 6: 2891 chars, 486 words
#       Piece 7: 3191 chars, 533 words
#       Piece 8: 3230 chars, 528 words
#       Piece 9: 3249 chars, 560 words
#       Piece 10: 3259 chars, 556 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'Home
# Instructors
# Lessons
# Adult Lessons
# Junior Lessons
# Junior Academy
# PGA Camps
# PGA Junior League
# Tin...' (2484 chars)
#
# 📝 Parsing content for SHOP (Row 10)
#    Expected count: 4
#    Content length: 2484 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 4 raw pieces
#    🧹 After cleaning: 4 valid pieces
#       Piece 1: 836 chars, 125 words
#       Piece 2: 836 chars, 125 words
#       Piece 3: 553 chars, 89 words
#       Piece 4: 163 chars, 29 words
#    ✂️  Taking first 4 pieces
#          ✅ Added 4 pieces to row data
#       Row 10 final data: ['ABOUT_US', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#
#    🔍 Processing row 11...
#       Metadata: 'ABOUT_US=1,EBOOK=0,COURSES=1,RECENT_BLOG=4,TESTIMONIALS=0,WEBINAR=0,SERVICES=1,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 1
#       Found: EBOOK = 0
#       Found: COURSES = 1
#       Found: RECENT_BLOG = 4
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 1
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 1, 'EBOOK': 0, 'COURSES': 1, 'RECENT_BLOG': 4, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 1, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'Say hello to your team
# We are a family owned and operated company who loves working with brands who ...' (3719 chars)
#
# 📝 Parsing content for ABOUT_US (Row 11)
#    Expected count: 1
#    Content length: 3719 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 3719 chars, 557 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Forest Path
# Food for thought
# Uncategorized
# March 23, 2013
# Forest Path
# Even the all-powerful Pointing...' (169 chars)
#
# 📝 Parsing content for COURSES (Row 11)
#    Expected count: 1
#    Content length: 169 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 169 chars, 29 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'Forest Path
# Food for thought
# Uncategorized
# March 23, 2013
# Forest Path
# Even the all-powerful Pointing...' (3335 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 11)
#    Expected count: 4
#    Content length: 3335 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 4 raw pieces
#    🧹 After cleaning: 4 valid pieces
#       Piece 1: 169 chars, 29 words
#       Piece 2: 153 chars, 26 words
#       Piece 3: 64 chars, 6 words
#       Piece 4: 2853 chars, 501 words
#    ✂️  Taking first 4 pieces
#          ✅ Added 4 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'We Offer Awesome Services
# Amazon SEO
# Forecasting & Supply Chain
# Amazon Marketing
# Account Management
# ...' (3201 chars)
#
# 📝 Parsing content for SERVICES (Row 11)
#    Expected count: 1
#    Content length: 3201 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 3201 chars, 490 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 11 final data: ['ABOUT_US', 'COURSES', 'RECENT_BLOG', 'SERVICES']
#
#    🔍 Processing row 12...
#       Metadata: 'ABOUT_US=1,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=1,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 1
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 1
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 1, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 1, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'OUR
# ABOUT
# US
# IS ALL
# ABOUT
# YOU
# THE WORDS
# “YOU” AND “YOUR”
# ARE PREVALENT IN
# OUR CORE VALUES
# Start With...' (1155 chars)
#
# 📝 Parsing content for ABOUT_US (Row 12)
#    Expected count: 1
#    Content length: 1155 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 1155 chars, 171 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Website Terms of Service
# Last Modified: 06/11/25
# Acceptance of the Terms of Service
# Dexios Services,...' (23959 chars)
#
# 📝 Parsing content for SERVICES (Row 12)
#    Expected count: 1
#    Content length: 23959 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 23959 chars, 3946 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 12 final data: ['ABOUT_US', 'SERVICES']
#
#    🔍 Processing row 13...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=1,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 1
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 1, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Top Level IPC Classifications
# The section, Top Class and Sub Class of an IPC classification.
# Was thi...' (528 chars)
#
# 📝 Parsing content for COURSES (Row 13)
#    Expected count: 1
#    Content length: 528 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 528 chars, 80 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 13 final data: ['COURSES']
#
#    🔍 Processing row 14...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 14 final data: []
#
#    🔍 Processing row 15...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=2,RECENT_BLOG=5,TESTIMONIALS=0,WEBINAR=2,SERVICES=2,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 2
#       Found: RECENT_BLOG = 5
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 2
#       Found: SERVICES = 2
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 2, 'RECENT_BLOG': 5, 'TESTIMONIALS': 0, 'WEBINAR': 2, 'SERVICES': 2, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ✅ Count > 0, processing...
#          Content preview: 'Leadership, Sales, Team Building
# & Communication Training
# Find Your Training Center
# Let's Connect
# Gr...' (8699 chars)
#
# 📝 Parsing content for COURSES (Row 15)
#    Expected count: 2
#    Content length: 8699 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 2761 chars, 401 words
#       Piece 2: 5906 chars, 887 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'This site uses cookies. By navigating the site, you consent to our use of cookies.
# Accept
# You Regist...' (11363 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 15)
#    Expected count: 5
#    Content length: 11363 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 3 raw pieces
#    🧹 After cleaning: 3 valid pieces
#       Piece 1: 5244 chars, 803 words
#       Piece 2: 2431 chars, 405 words
#       Piece 3: 3624 chars, 596 words
#    ⚠️  Expected 5, only got 3
#          ✅ Added 3 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'This site uses cookies. By navigating the site, you consent to our use of cookies.
# Accept
# You Regist...' (12636 chars)
#
# 📝 Parsing content for WEBINAR (Row 15)
#    Expected count: 2
#    Content length: 12636 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 5244 chars, 803 words
#       Piece 2: 7360 chars, 1073 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'Extended DISC Assessments
# Learn How Your Team Prefers To Interact With Others
# Find Your Training Cen...' (9184 chars)
#
# 📝 Parsing content for SERVICES (Row 15)
#    Expected count: 2
#    Content length: 9184 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 2 raw pieces
#    🧹 After cleaning: 2 valid pieces
#       Piece 1: 4841 chars, 708 words
#       Piece 2: 4311 chars, 630 words
#    ✂️  Taking first 2 pieces
#          ✅ Added 2 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 15 final data: ['COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES']
#
#    🔍 Processing row 16...
#       Metadata: 'ABOUT_US=10,EBOOK=0,COURSES=0,RECENT_BLOG=4,TESTIMONIALS=10,WEBINAR=1,SERVICES=10,PODCAST=0,SHOP=10'
#       Found: ABOUT_US = 10
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 4
#       Found: TESTIMONIALS = 10
#       Found: WEBINAR = 1
#       Found: SERVICES = 10
#       Found: PODCAST = 0
#       Found: SHOP = 10
#       Category counts: {'ABOUT_US': 10, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 4, 'TESTIMONIALS': 10, 'WEBINAR': 1, 'SERVICES': 10, 'PODCAST': 0, 'SHOP': 10}
#       🔍 Checking category: ABOUT_US
#          ✅ Count > 0, processing...
#          Content preview: 'ABOUT US
# OUR HISTORY
# Sansome Pacific Properties, Inc. was established in San Francisco in 1998, spec...' (31318 chars)
#
# 📝 Parsing content for ABOUT_US (Row 16)
#    Expected count: 10
#    Content length: 31318 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 14556 chars, 2181 words
#       Piece 2: 207 chars, 28 words
#       Piece 3: 189 chars, 26 words
#       Piece 4: 14556 chars, 2181 words
#       Piece 5: 171 chars, 23 words
#       Piece 6: 205 chars, 30 words
#       Piece 7: 213 chars, 32 words
#       Piece 8: 539 chars, 77 words
#       Piece 9: 189 chars, 26 words
#       Piece 10: 205 chars, 26 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ✅ Count > 0, processing...
#          Content preview: 'BuddyPress Group
# Home
# >
# Grid Templates
# >
# BuddyPress Group
# Recent Posts
# Hello world!
# Recent Comments
# ...' (2497 chars)
#
# 📝 Parsing content for RECENT_BLOG (Row 16)
#    Expected count: 4
#    Content length: 2497 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 4 raw pieces
#    🧹 After cleaning: 4 valid pieces
#       Piece 1: 200 chars, 28 words
#       Piece 2: 185 chars, 27 words
#       Piece 3: 221 chars, 31 words
#       Piece 4: 1795 chars, 283 words
#    ✂️  Taking first 4 pieces
#          ✅ Added 4 pieces to row data
#       🔍 Checking category: TESTIMONIALS
#          ✅ Count > 0, processing...
#          Content preview: '43 + STATES
# Over $3 billion of acquired commercial real estate since inception.
# 15,000,000 +
# Propert...' (2681 chars)
#
# 📝 Parsing content for TESTIMONIALS (Row 16)
#    Expected count: 10
#    Content length: 2681 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 239 chars, 35 words
#       Piece 2: 237 chars, 33 words
#       Piece 3: 274 chars, 41 words
#       Piece 4: 233 chars, 26 words
#       Piece 5: 219 chars, 26 words
#       Piece 6: 251 chars, 26 words
#       Piece 7: 251 chars, 26 words
#       Piece 8: 239 chars, 26 words
#       Piece 9: 235 chars, 26 words
#       Piece 10: 215 chars, 26 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: WEBINAR
#          ✅ Count > 0, processing...
#          Content preview: 'Main Olive Center
# Home
# >
# Locations
# >
# Main Olive Center
# Recent Posts
# Hello world!
# Recent Comments
# Arc...' (197 chars)
#
# 📝 Parsing content for WEBINAR (Row 16)
#    Expected count: 1
#    Content length: 197 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 197 chars, 29 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: SERVICES
#          ✅ Count > 0, processing...
#          Content preview: 'expertise_single
# Home
# >
# Expertise
# >
# expertise_single
# Recent Posts
# Hello world!
# Recent Comments
# Archi...' (2482 chars)
#
# 📝 Parsing content for SERVICES (Row 16)
#    Expected count: 10
#    Content length: 2482 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 195 chars, 25 words
#       Piece 2: 195 chars, 25 words
#       Piece 3: 187 chars, 25 words
#       Piece 4: 187 chars, 25 words
#       Piece 5: 187 chars, 25 words
#       Piece 6: 193 chars, 25 words
#       Piece 7: 169 chars, 25 words
#       Piece 8: 171 chars, 25 words
#       Piece 9: 171 chars, 25 words
#       Piece 10: 539 chars, 77 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ✅ Count > 0, processing...
#          Content preview: 'complete e-commerce template
# Home
# >
# Grid Templates
# >
# complete e-commerce template
# Recent Posts
# Hello...' (4472 chars)
#
# 📝 Parsing content for SHOP (Row 16)
#    Expected count: 10
#    Content length: 4472 characters
#    🔍 Trying 5 different delimiters...
#    ✅ Found delimiter #1: '--- NEXT CONTENT FROM HERE ---...'
#    📊 Split into 10 raw pieces
#    🧹 After cleaning: 10 valid pieces
#       Piece 1: 224 chars, 30 words
#       Piece 2: 251 chars, 26 words
#       Piece 3: 251 chars, 26 words
#       Piece 4: 259 chars, 35 words
#       Piece 5: 539 chars, 77 words
#       Piece 6: 289 chars, 38 words
#       Piece 7: 625 chars, 101 words
#       Piece 8: 674 chars, 105 words
#       Piece 9: 541 chars, 83 words
#       Piece 10: 531 chars, 83 words
#    ✂️  Taking first 10 pieces
#          ✅ Added 10 pieces to row data
#       Row 16 final data: ['ABOUT_US', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'SHOP']
#
#    🔍 Processing row 17...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=1,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 1
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 1, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ✅ Count > 0, processing...
#          Content preview: 'Podcast Series
# Embark on a journey through the entire spectrum of Project 180 with our curated playl...' (414 chars)
#
# 📝 Parsing content for PODCAST (Row 17)
#    Expected count: 1
#    Content length: 414 characters
#    🔍 Trying 5 different delimiters...
#    ℹ️  No delimiter found, treating as single piece
#    🧹 After cleaning: 1 valid pieces
#       Piece 1: 414 chars, 64 words
#    ✅ Expected 1, got 1 - returning as is
#          ✅ Added 1 pieces to row data
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 17 final data: ['PODCAST']
#
#    🔍 Processing row 18...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 18 final data: []
#
#    🔍 Processing row 19...
#       Metadata: 'ABOUT_US=0,EBOOK=0,COURSES=0,RECENT_BLOG=0,TESTIMONIALS=0,WEBINAR=0,SERVICES=0,PODCAST=0,SHOP=0'
#       Found: ABOUT_US = 0
#       Found: EBOOK = 0
#       Found: COURSES = 0
#       Found: RECENT_BLOG = 0
#       Found: TESTIMONIALS = 0
#       Found: WEBINAR = 0
#       Found: SERVICES = 0
#       Found: PODCAST = 0
#       Found: SHOP = 0
#       Category counts: {'ABOUT_US': 0, 'EBOOK': 0, 'COURSES': 0, 'RECENT_BLOG': 0, 'TESTIMONIALS': 0, 'WEBINAR': 0, 'SERVICES': 0, 'PODCAST': 0, 'SHOP': 0}
#       🔍 Checking category: ABOUT_US
#          ❌ Skipping (count = 0)
#       🔍 Checking category: EBOOK
#          ❌ Skipping (count = 0)
#       🔍 Checking category: COURSES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: RECENT_BLOG
#          ❌ Skipping (count = 0)
#       🔍 Checking category: TESTIMONIALS
#          ❌ Skipping (count = 0)
#       🔍 Checking category: WEBINAR
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SERVICES
#          ❌ Skipping (count = 0)
#       🔍 Checking category: PODCAST
#          ❌ Skipping (count = 0)
#       🔍 Checking category: SHOP
#          ❌ Skipping (count = 0)
#       Row 19 final data: []
#
#    🔍 Processing row 20...
# ...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 31198 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 6827 characters
#    📤 Response preview: 'Are You Ready to Launch Your Own Physical Therapy Practice?
# February 20, 2025
# Blog Post
# Starting a physical therapy practice is an exciting venture that requires hard work, dedication, and a solid bus...'
#          ✅ AI processing complete
#       ✅ Row 980 output: 6827 chars
#
#    📋 Processing row 981 (data index 979)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 981 output: 10 chars
#       📤 Writing batch to range: Sheet2!P977:P981
#
#    📤 Writing batch #157 to sheet range: Sheet2!P977:P981
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #157 for RECENT_BLOG
#
#    📋 Processing row 982 (data index 980)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 982 output: 10 chars
#
#    📋 Processing row 983 (data index 981)...
#       Found 3 pieces for RECENT_BLOG
#       🔄 Multiple pieces (3) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 983, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 3 pieces to format
#    Formatting piece 1: 388 chars
#    Formatting piece 2: 1794 chars
#    Formatting piece 3: 1851 chars
#    ✅ Formatted output: 4270 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 4270 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 1794 characters
#    📤 Response preview: 'Friday, May 21st, 2021 – The Contracting Officers at the Hawaii Army National Guard (HIARNG) have renewed Tridant’s Case Management Medical Readiness contracts. During our 5 years providing Case Manag...'
#          ✅ AI processing complete
#       ✅ Row 983 output: 1794 chars
#
#    📋 Processing row 984 (data index 982)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 984, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 822 chars
#    Formatting piece 2: 976 chars
#    Formatting piece 3: 1329 chars
#    Formatting piece 4: 323 chars
#    Formatting piece 5: 988 chars
#    Formatting piece 6: 1426 chars
#    Formatting piece 7: 2113 chars
#    Formatting piece 8: 820 chars
#    Formatting piece 9: 328 chars
#    Formatting piece 10: 2266 chars
#    ✅ Formatted output: 12183 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 12183 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 1505 characters
#    📤 Response preview: 'Celebrate Live Music in Corning
# WELCOME! Civic Music presents an eclectic mix of musical performances ranging from classical and jazz to gospel, swing, and rock in an affordable six-concert fall-to-sp...'
#          ✅ AI processing complete
#       ✅ Row 984 output: 1505 chars
#
#    📋 Processing row 985 (data index 983)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 985 output: 10 chars
#
#    📋 Processing row 986 (data index 984)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 986, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 576 chars
#    Formatting piece 2: 576 chars
#    Formatting piece 3: 576 chars
#    Formatting piece 4: 576 chars
#    Formatting piece 5: 576 chars
#    Formatting piece 6: 576 chars
#    Formatting piece 7: 576 chars
#    Formatting piece 8: 576 chars
#    Formatting piece 9: 576 chars
#    Formatting piece 10: 576 chars
#    ✅ Formatted output: 6550 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 6550 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 0 characters
#    📤 Response preview: '...'
#          ✅ AI processing complete
#       ✅ Row 986 output: 0 chars
#       📤 Writing batch to range: Sheet2!P982:P986
#
#    📤 Writing batch #158 to sheet range: Sheet2!P982:P986
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #158 for RECENT_BLOG
#
#    📋 Processing row 987 (data index 985)...
#       Found 7 pieces for RECENT_BLOG
#       🔄 Multiple pieces (7) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 987, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 7 pieces to format
#    Formatting piece 1: 10316 chars
#    Formatting piece 2: 2735 chars
#    Formatting piece 3: 776 chars
#    Formatting piece 4: 10185 chars
#    Formatting piece 5: 393 chars
#    Formatting piece 6: 1176 chars
#    Formatting piece 7: 17830 chars
#    ✅ Formatted output: 43977 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 43977 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 452 characters
#    📤 Response preview: 'Join Us! OU- College of Arts & Sciences Golf Classic 2025!
# The College of Arts and Sciences at Oakland University invites you to support our Annual Golf Classic, benefiting the Department of Biologic...'
#          ✅ AI processing complete
#       ✅ Row 987 output: 452 chars
#
#    📋 Processing row 988 (data index 986)...
#       Found 3 pieces for RECENT_BLOG
#       🔄 Multiple pieces (3) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 988, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'RECENT_BLOG', 'TESTIMONIALS', 'SERVICES']
#    Found 3 pieces to format
#    Formatting piece 1: 104 chars
#    Formatting piece 2: 695 chars
#    Formatting piece 3: 1837 chars
#    ✅ Formatted output: 2871 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 2871 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 178 characters
#    📤 Response preview: 'Building Inspiring Spaces
# Vivamus sed consectetur tellus dolor sit amet, consectetur adipiscing lorem elit sadip ipsum ets ficilis uns.
# GET A FREE QUOTE
# Only takes a few seconds!...'
#          ✅ AI processing complete
#       ✅ Row 988 output: 178 chars
#
#    📋 Processing row 989 (data index 987)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 989 output: 10 chars
#
#    📋 Processing row 990 (data index 988)...
#       Found 5 pieces for RECENT_BLOG
#       🔄 Multiple pieces (5) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 990, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'RECENT_BLOG', 'WEBINAR', 'SERVICES']
#    Found 5 pieces to format
#    Formatting piece 1: 313 chars
#    Formatting piece 2: 441 chars
#    Formatting piece 3: 258 chars
#    Formatting piece 4: 1287 chars
#    Formatting piece 5: 3605 chars
#    ✅ Formatted output: 6297 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 6297 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 3214 characters
#    📤 Response preview: 'Empowering Veteran Entrepreneurs: The Essential Role of NVBDC Certification
#
# Introduction
# The National Veteran Business Development Council (NVBDC) is a pivotal organization in the landscape of vetera...'
#          ✅ AI processing complete
#       ✅ Row 990 output: 3214 chars
#
#    📋 Processing row 991 (data index 989)...
#       Found 1 pieces for RECENT_BLOG
#       📋 Single piece -> copying directly (80 chars)
#       ✅ Row 991 output: 80 chars
#       📤 Writing batch to range: Sheet2!P987:P991
#
#    📤 Writing batch #159 to sheet range: Sheet2!P987:P991
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #159 for RECENT_BLOG
#
#    📋 Processing row 992 (data index 990)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 992 output: 10 chars
#
#    📋 Processing row 993 (data index 991)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 993 output: 10 chars
#
#    📋 Processing row 994 (data index 992)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 994 output: 10 chars
#
#    📋 Processing row 995 (data index 993)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 995, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'WEBINAR', 'SERVICES', 'PODCAST', 'SHOP']
#    Found 10 pieces to format
#    Formatting piece 1: 420 chars
#    Formatting piece 2: 359 chars
#    Formatting piece 3: 444 chars
#    Formatting piece 4: 321 chars
#    Formatting piece 5: 395 chars
#    Formatting piece 6: 444 chars
#    Formatting piece 7: 360 chars
#    Formatting piece 8: 359 chars
#    Formatting piece 9: 418 chars
#    Formatting piece 10: 401 chars
#    ✅ Formatted output: 4701 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 4701 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 1965 characters
#    📤 Response preview: 'Religious web design: 6 helpful tips for designing your church website
# By
# Katherine Vaughan
# Churches & Religious Organizations
# ,
# Web Design
# ,
# Website Experts Series
# ,
# Website Redesign
# In today’s digit...'
#          ✅ AI processing complete
#       ✅ Row 995 output: 1965 chars
#
#    📋 Processing row 996 (data index 994)...
#       Found 2 pieces for RECENT_BLOG
#       🔄 Multiple pieces (2) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 996, Category: RECENT_BLOG
#    Row data keys: ['ABOUT_US', 'EBOOK', 'COURSES', 'RECENT_BLOG', 'TESTIMONIALS', 'SERVICES', 'SHOP']
#    Found 2 pieces to format
#    Formatting piece 1: 634 chars
#    Formatting piece 2: 2225 chars
#    ✅ Formatted output: 3016 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 3016 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 2463 characters
#    📤 Response preview: 'Unlock the potential of AI-driven predictive analytics to elevate your decision-making process. Predictive analytics is a powerful tool that leverages advanced algorithms and machine learning techniqu...'
#          ✅ AI processing complete
#       ✅ Row 996 output: 2463 chars
#       📤 Writing batch to range: Sheet2!P992:P996
#
#    📤 Writing batch #160 to sheet range: Sheet2!P992:P996
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #160 for RECENT_BLOG
#
#    📋 Processing row 997 (data index 995)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 997 output: 10 chars
#
#    📋 Processing row 998 (data index 996)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 998 output: 10 chars
#
#    📋 Processing row 999 (data index 997)...
#       Found 10 pieces for RECENT_BLOG
#       🔄 Multiple pieces (10) - applying processing logic...
#          🤖 RECENT_BLOG category -> AI processing
#
# 🤖 Formatting content for AI processing...
#    Row: 999, Category: RECENT_BLOG
#    Row data keys: ['EBOOK', 'COURSES', 'RECENT_BLOG', 'WEBINAR', 'SERVICES']
#    Found 10 pieces to format
#    Formatting piece 1: 764 chars
#    Formatting piece 2: 7323 chars
#    Formatting piece 3: 5960 chars
#    Formatting piece 4: 2543 chars
#    Formatting piece 5: 4287 chars
#    Formatting piece 6: 3483 chars
#    Formatting piece 7: 7234 chars
#    Formatting piece 8: 6282 chars
#    Formatting piece 9: 8961 chars
#    Formatting piece 10: 1191 chars
#    ✅ Formatted output: 48830 total chars
#          🚀 Sending to AI processing...
#
# 🚀 Processing with AI (LangChain)...
#    Category: RECENT_BLOG
#    Input length: 48830 characters
# 🔗 Creating LangChain pipeline for category: RECENT_BLOG
#    📝 Using prompt template for RECENT_BLOG
#    🤖 Initializing ChatOpenAI with GPT-4
#    ✅ Chain created successfully
#    🔄 Sending to AI...
#    ✅ AI processing successful!
#    📤 Response length: 6884 characters
#    📤 Response preview: 'STEM careers are for women, too. Infuzion Solutions' CEO proves it.
# It is no secret that today, women are significantly underrepresented in science, technology, engineering, and mathematics (STEM) (So...'
#          ✅ AI processing complete
#       ✅ Row 999 output: 6884 chars
#
#    📋 Processing row 1000 (data index 998)...
#       Found 1 pieces for RECENT_BLOG
#       📋 Single piece -> copying directly (4156 chars)
#       ✅ Row 1000 output: 4156 chars
#
#    📋 Processing row 1001 (data index 999)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 1001 output: 10 chars
#       📤 Writing batch to range: Sheet2!P997:P1001
#
#    📤 Writing batch #161 to sheet range: Sheet2!P997:P1001
#    📊 Writing 5 values
#    ✅ Successfully wrote batch #161 for RECENT_BLOG
#
#    📋 Processing row 1002 (data index 1000)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 1002 output: 10 chars
#
#    📋 Processing row 1003 (data index 1001)...
#       Found 0 pieces for RECENT_BLOG
#       ❌ No pieces found -> 'no content'
#       ✅ Row 1003 output: 10 chars
#    📤 Writing final batch to range: Sheet2!P1002:P1003
#
#    📤 Writing batch #final to sheet range: Sheet2!P1002:P1003
#    📊 Writing 2 values
#    ✅ Successfully wrote batch #final for RECENT_BLOG
# ✅ Completed blog category: RECENT_BLOG
#
# 🎉 Pipeline completed successfully!
